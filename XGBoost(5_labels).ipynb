# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/thesis_2025/blob/main/XGBoost(5_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================================
# STEP 1: IMPORT LIBRARIES AND SETUP
# ============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                           f1_score, confusion_matrix, classification_report)
import xgboost as xgb
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

# Set style for better plots
plt.style.use('default')
sns.set_palette("husl")

print("✅ Step 1 Complete: All libraries imported successfully!")
# Out:
# ✅ Step 1 Complete: All libraries imported successfully!

# %%
# ============================================================================
# STEP 2: LOAD THE DATASETS
# ============================================================================

# Load the three CSV files
print("📂 Loading datasets...")

try:
    train_df = pd.read_csv("/content/drive/MyDrive/UpdatedDataset/train.csv")
    val_df = pd.read_csv("/content/drive/MyDrive/UpdatedDataset/validation.csv")
    test_df = pd.read_csv("/content/drive/MyDrive/UpdatedDataset/test.csv")

    print(f"✅ Training data loaded: {train_df.shape}")
    print(f"✅ Validation data loaded: {val_df.shape}")
    print(f"✅ Test data loaded: {test_df.shape}")

    # Display basic info about the data
    print("\n📊 Dataset Information:")
    print(f"Training set columns: {len(train_df.columns)}")
    print(f"Sample of column names: {list(train_df.columns[:5])}")
    print(f"Production range in training: {train_df['Production (M.Ton)'].min():.2f} - {train_df['Production (M.Ton)'].max():.2f}")

except FileNotFoundError as e:
    print("❌ Error: CSV files not found. Please ensure train.csv, validation.csv, and test.csv are in the current directory.")
    print("Current working directory files should include your CSV files.")

print("\n✅ Step 2 Complete: Data loading finished!")
# Out:
# 📂 Loading datasets...
# ✅ Training data loaded: (3942, 84)
# ✅ Validation data loaded: (845, 84)
# ✅ Test data loaded: (845, 84)
#
# 📊 Dataset Information:
# Training set columns: 84
# Sample of column names: ['Production (M.Ton)', 'Area (Acres)', 'Temperature at 2 Meters Range (C)', 'Year', 'soil_temperature_0_to_7cm(C)']
# Production range in training: 0.00 - 544979.50
#
# ✅ Step 2 Complete: Data loading finished!

# %%
# ============================================================================
# STEP 3: CREATE PRODUCTION CATEGORIES (5 LEVELS)
# ============================================================================

def create_production_categories(df, thresholds=None):
    """Create 5 production level categories"""
    df = df.copy()
    production_col = 'Production (M.Ton)'

    # Calculate thresholds based on training data quantiles
    if thresholds is None:
        thresholds = [
            df[production_col].quantile(0.2),   # Very Low: 0-20%
            df[production_col].quantile(0.4),   # Low: 20-40%
            df[production_col].quantile(0.6),   # Medium: 40-60%
            df[production_col].quantile(0.8),   # High: 60-80%
            df[production_col].max()            # Very High: 80-100%
        ]

    # Create categories
    conditions = [
        df[production_col] <= thresholds[0],
        (df[production_col] > thresholds[0]) & (df[production_col] <= thresholds[1]),
        (df[production_col] > thresholds[1]) & (df[production_col] <= thresholds[2]),
        (df[production_col] > thresholds[2]) & (df[production_col] <= thresholds[3]),
        df[production_col] > thresholds[3]
    ]

    class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    df['Production_Category'] = np.select(conditions, class_names, default='Medium')

    return df, thresholds

# Apply categorization
print("🏷️ Creating production categories...")

# Create categories using training data thresholds
train_df_cat, production_thresholds = create_production_categories(train_df)
val_df_cat, _ = create_production_categories(val_df, production_thresholds)
test_df_cat, _ = create_production_categories(test_df, production_thresholds)

# Display category distribution
print("\n📊 Production Category Distribution:")
print("Training set:")
print(train_df_cat['Production_Category'].value_counts())
print("\nValidation set:")
print(val_df_cat['Production_Category'].value_counts())
print("\nTest set:")
print(test_df_cat['Production_Category'].value_counts())

print(f"\n📏 Production thresholds used:")
class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
for i, (name, threshold) in enumerate(zip(class_names, production_thresholds)):
    if i == 0:
        print(f"{name}: ≤ {threshold:.2f}")
    else:
        print(f"{name}: {production_thresholds[i-1]:.2f} < x ≤ {threshold:.2f}")

print("\n✅ Step 3 Complete: Production categories created!")
# Out:
# 🏷️ Creating production categories...
#
# 📊 Production Category Distribution:
# Training set:
# Production_Category
# Very Low     793
# Very High    789
# High         788
# Medium       786
# Low          786
# Name: count, dtype: int64
#
# Validation set:
# Production_Category
# Medium       191
# Very Low     185
# Very High    169
# High         160
# Low          140
# Name: count, dtype: int64
#
# Test set:
# Production_Category
# High         175
# Very High    173
# Very Low     172
# Medium       167
# Low          158
# Name: count, dtype: int64
#
# 📏 Production thresholds used:
# Very Low: ≤ 578.00
# Low: 578.00 < x ≤ 1463.00
# Medium: 1463.00 < x ≤ 3119.52
# High: 3119.52 < x ≤ 6540.92
# Very High: 6540.92 < x ≤ 544979.50
#
# ✅ Step 3 Complete: Production categories created!

# %%
# ============================================================================
# STEP 4: PREPARE FEATURES AND TARGETS
# ============================================================================

def prepare_features_targets(df):
    """Prepare features and target variables"""
    # Select feature columns (exclude production columns)
    feature_cols = [col for col in df.columns if col not in ['Production (M.Ton)', 'Production_Category']]

    X = df[feature_cols].copy()
    y = df['Production_Category'].copy()

    # Handle missing values by filling with mean
    X_filled = X.fillna(X.mean())

    return X_filled, y, feature_cols

print("🔧 Preparing features and targets...")

# Prepare data for all sets
X_train, y_train, feature_names = prepare_features_targets(train_df_cat)
X_val, y_val, _ = prepare_features_targets(val_df_cat)
X_test, y_test, _ = prepare_features_targets(test_df_cat)

# Encode target labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

print(f"✅ Features prepared: {X_train.shape[1]} features")
print(f"✅ Feature names stored: {len(feature_names)} features")
print(f"✅ Labels encoded: {len(label_encoder.classes_)} classes")
print(f"Class mapping: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")

print("\n✅ Step 4 Complete: Features and targets prepared!")
# Out:
# 🔧 Preparing features and targets...
# ✅ Features prepared: 83 features
# ✅ Feature names stored: 83 features
# ✅ Labels encoded: 5 classes
# Class mapping: {'High': 0, 'Low': 1, 'Medium': 2, 'Very High': 3, 'Very Low': 4}
#
# ✅ Step 4 Complete: Features and targets prepared!

# %%
# ============================================================================
# STEP 5: TRAIN XGBOOST MODEL WITH REAL-TIME PROGRESS DISPLAY
# ============================================================================

def train_xgboost_with_realtime_display(X_train, y_train, X_val, y_val, n_epochs=250):
    """Train XGBoost model with real-time progress display"""

    print("🚀 Training model with real-time progress display...")
    print("Training model with history tracking...")

    # Initialize training history storage
    training_history = {
        'epochs': [],
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': []
    }

    # Train model iteratively to show progress
    model = None
    best_val_loss = float('inf')
    patience_counter = 0
    early_stopping_rounds = 50

    for epoch in range(1, n_epochs + 1):
        # Create model with current number of estimators
        current_model = XGBClassifier(
            n_estimators=epoch,
            max_depth=6,
            learning_rate=0.1,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42,
            eval_metric='mlogloss'
        )

        # Train model
        eval_set = [(X_train, y_train), (X_val, y_val)]
        current_model.fit(
            X_train, y_train,
            eval_set=eval_set,
            verbose=False
        )

        # Make predictions
        train_pred = current_model.predict(X_train)
        val_pred = current_model.predict(X_val)

        # Calculate accuracies
        train_acc = accuracy_score(y_train, train_pred)
        val_acc = accuracy_score(y_val, val_pred)

        # Get losses from evaluation results
        train_loss = current_model.evals_result_['validation_0']['mlogloss'][-1]
        val_loss = current_model.evals_result_['validation_1']['mlogloss'][-1]

        # Store history
        training_history['epochs'].append(epoch)
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_acc'].append(train_acc)
        training_history['val_acc'].append(val_acc)

        # Display progress
        print(f"Epoch {epoch:3d}/{n_epochs} - "
              f"Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, "
              f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Early stopping logic
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            model = current_model  # Save best model
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= early_stopping_rounds:
            print(f"Early stopping at epoch {epoch}")
            break

    print("Training completed.")

    # Store best iteration info in training history for reference
    training_history['best_iteration'] = len(training_history['epochs'])

    return model, training_history

# Train the model with real-time display
model, training_history = train_xgboost_with_realtime_display(
    X_train.values, y_train_encoded,
    X_val.values, y_val_encoded,
    n_epochs=250
)

print(f"\n✅ Training complete! Best iteration: {training_history.get('best_iteration', 'N/A')}")
print("\n✅ Step 5 Complete: Model training with real-time display finished!")
# Out:
# 🚀 Training model with real-time progress display...
# Training model with history tracking...
# Epoch   1/250 - Train Acc: 0.7585, Val Acc: 0.7219, Train Loss: 1.4884, Val Loss: 1.4917
# Epoch   2/250 - Train Acc: 0.8014, Val Acc: 0.7385, Train Loss: 1.3878, Val Loss: 1.3987
# Epoch   3/250 - Train Acc: 0.8176, Val Acc: 0.7408, Train Loss: 1.2919, Val Loss: 1.3054
# Epoch   4/250 - Train Acc: 0.8250, Val Acc: 0.7515, Train Loss: 1.2181, Val Loss: 1.2349
# Epoch   5/250 - Train Acc: 0.8293, Val Acc: 0.7716, Train Loss: 1.1447, Val Loss: 1.1688
# Epoch   6/250 - Train Acc: 0.8283, Val Acc: 0.7704, Train Loss: 1.1022, Val Loss: 1.1310
# Epoch   7/250 - Train Acc: 0.8351, Val Acc: 0.7775, Train Loss: 1.0495, Val Loss: 1.0817
# Epoch   8/250 - Train Acc: 0.8349, Val Acc: 0.7621, Train Loss: 0.9973, Val Loss: 1.0345
# Epoch   9/250 - Train Acc: 0.8364, Val Acc: 0.7680, Train Loss: 0.9502, Val Loss: 0.9898
# Epoch  10/250 - Train Acc: 0.8369, Val Acc: 0.7751, Train Loss: 0.9061, Val Loss: 0.9485
# Epoch  11/250 - Train Acc: 0.8364, Val Acc: 0.7692, Train Loss: 0.8716, Val Loss: 0.9187
# Epoch  12/250 - Train Acc: 0.8417, Val Acc: 0.7692, Train Loss: 0.8349, Val Loss: 0.8844
# Epoch  13/250 - Train Acc: 0.8460, Val Acc: 0.7763, Train Loss: 0.8056, Val Loss: 0.8572
# Epoch  14/250 - Train Acc: 0.8453, Val Acc: 0.7740, Train Loss: 0.7751, Val Loss: 0.8315
# Epoch  15/250 - Train Acc: 0.8519, Val Acc: 0.7763, Train Loss: 0.7554, Val Loss: 0.8149
# Epoch  16/250 - Train Acc: 0.8531, Val Acc: 0.7834, Train Loss: 0.7300, Val Loss: 0.7918
# Epoch  17/250 - Train Acc: 0.8562, Val Acc: 0.7893, Train Loss: 0.7089, Val Loss: 0.7730
# Epoch  18/250 - Train Acc: 0.8577, Val Acc: 0.7905, Train Loss: 0.6889, Val Loss: 0.7554
# Epoch  19/250 - Train Acc: 0.8590, Val Acc: 0.7905, Train Loss: 0.6669, Val Loss: 0.7355
# Epoch  20/250 - Train Acc: 0.8587, Val Acc: 0.7929, Train Loss: 0.6497, Val Loss: 0.7214
# Epoch  21/250 - Train Acc: 0.8625, Val Acc: 0.7941, Train Loss: 0.6302, Val Loss: 0.7054
# Epoch  22/250 - Train Acc: 0.8640, Val Acc: 0.7929, Train Loss: 0.6183, Val Loss: 0.6960
# Epoch  23/250 - Train Acc: 0.8635, Val Acc: 0.7953, Train Loss: 0.6064, Val Loss: 0.6877
# Epoch  24/250 - Train Acc: 0.8658, Val Acc: 0.7976, Train Loss: 0.5947, Val Loss: 0.6769
# Epoch  25/250 - Train Acc: 0.8686, Val Acc: 0.7976, Train Loss: 0.5821, Val Loss: 0.6667
# Epoch  26/250 - Train Acc: 0.8699, Val Acc: 0.7976, Train Loss: 0.5700, Val Loss: 0.6568
# Epoch  27/250 - Train Acc: 0.8737, Val Acc: 0.8000, Train Loss: 0.5599, Val Loss: 0.6493
# Epoch  28/250 - Train Acc: 0.8762, Val Acc: 0.7964, Train Loss: 0.5476, Val Loss: 0.6391
# Epoch  29/250 - Train Acc: 0.8765, Val Acc: 0.7988, Train Loss: 0.5382, Val Loss: 0.6309
# Epoch  30/250 - Train Acc: 0.8803, Val Acc: 0.8000, Train Loss: 0.5281, Val Loss: 0.6227
# Epoch  31/250 - Train Acc: 0.8851, Val Acc: 0.8024, Train Loss: 0.5177, Val Loss: 0.6138
# Epoch  32/250 - Train Acc: 0.8843, Val Acc: 0.8012, Train Loss: 0.5083, Val Loss: 0.6066
# Epoch  33/250 - Train Acc: 0.8866, Val Acc: 0.8024, Train Loss: 0.5019, Val Loss: 0.6016
# Epoch  34/250 - Train Acc: 0.8879, Val Acc: 0.8059, Train Loss: 0.4927, Val Loss: 0.5942
# Epoch  35/250 - Train Acc: 0.8869, Val Acc: 0.8071, Train Loss: 0.4857, Val Loss: 0.5892
# Epoch  36/250 - Train Acc: 0.8884, Val Acc: 0.8083, Train Loss: 0.4785, Val Loss: 0.5836
# Epoch  37/250 - Train Acc: 0.8912, Val Acc: 0.8071, Train Loss: 0.4707, Val Loss: 0.5780
# Epoch  38/250 - Train Acc: 0.8940, Val Acc: 0.8047, Train Loss: 0.4638, Val Loss: 0.5718
# Epoch  39/250 - Train Acc: 0.8940, Val Acc: 0.8083, Train Loss: 0.4567, Val Loss: 0.5661
# Epoch  40/250 - Train Acc: 0.8940, Val Acc: 0.8107, Train Loss: 0.4500, Val Loss: 0.5611
# Epoch  41/250 - Train Acc: 0.8970, Val Acc: 0.8142, Train Loss: 0.4435, Val Loss: 0.5563
# Epoch  42/250 - Train Acc: 0.8998, Val Acc: 0.8166, Train Loss: 0.4376, Val Loss: 0.5513
# Epoch  43/250 - Train Acc: 0.9016, Val Acc: 0.8189, Train Loss: 0.4301, Val Loss: 0.5458
# Epoch  44/250 - Train Acc: 0.9044, Val Acc: 0.8201, Train Loss: 0.4232, Val Loss: 0.5404
# Epoch  45/250 - Train Acc: 0.9054, Val Acc: 0.8213, Train Loss: 0.4180, Val Loss: 0.5362
# Epoch  46/250 - Train Acc: 0.9059, Val Acc: 0.8189, Train Loss: 0.4125, Val Loss: 0.5326
# Epoch  47/250 - Train Acc: 0.9072, Val Acc: 0.8189, Train Loss: 0.4073, Val Loss: 0.5280
# Epoch  48/250 - Train Acc: 0.9087, Val Acc: 0.8213, Train Loss: 0.4011, Val Loss: 0.5238
# Epoch  49/250 - Train Acc: 0.9097, Val Acc: 0.8178, Train Loss: 0.3953, Val Loss: 0.5196
# Epoch  50/250 - Train Acc: 0.9117, Val Acc: 0.8213, Train Loss: 0.3898, Val Loss: 0.5150
# Epoch  51/250 - Train Acc: 0.9105, Val Acc: 0.8189, Train Loss: 0.3848, Val Loss: 0.5113
# Epoch  52/250 - Train Acc: 0.9112, Val Acc: 0.8201, Train Loss: 0.3800, Val Loss: 0.5075
# Epoch  53/250 - Train Acc: 0.9130, Val Acc: 0.8178, Train Loss: 0.3768, Val Loss: 0.5053
# Epoch  54/250 - Train Acc: 0.9145, Val Acc: 0.8189, Train Loss: 0.3731, Val Loss: 0.5023
# Epoch  55/250 - Train Acc: 0.9150, Val Acc: 0.8213, Train Loss: 0.3690, Val Loss: 0.5004
# Epoch  56/250 - Train Acc: 0.9153, Val Acc: 0.8237, Train Loss: 0.3655, Val Loss: 0.4977
# Epoch  57/250 - Train Acc: 0.9168, Val Acc: 0.8249, Train Loss: 0.3605, Val Loss: 0.4948
# Epoch  58/250 - Train Acc: 0.9176, Val Acc: 0.8260, Train Loss: 0.3567, Val Loss: 0.4918
# Epoch  59/250 - Train Acc: 0.9191, Val Acc: 0.8237, Train Loss: 0.3536, Val Loss: 0.4903
# Epoch  60/250 - Train Acc: 0.9206, Val Acc: 0.8225, Train Loss: 0.3504, Val Loss: 0.4890
# Epoch  61/250 - Train Acc: 0.9206, Val Acc: 0.8260, Train Loss: 0.3467, Val Loss: 0.4872
# Epoch  62/250 - Train Acc: 0.9206, Val Acc: 0.8284, Train Loss: 0.3437, Val Loss: 0.4862
# Epoch  63/250 - Train Acc: 0.9234, Val Acc: 0.8284, Train Loss: 0.3401, Val Loss: 0.4850
# Epoch  64/250 - Train Acc: 0.9254, Val Acc: 0.8272, Train Loss: 0.3374, Val Loss: 0.4831
# Epoch  65/250 - Train Acc: 0.9264, Val Acc: 0.8260, Train Loss: 0.3338, Val Loss: 0.4813
# Epoch  66/250 - Train Acc: 0.9257, Val Acc: 0.8284, Train Loss: 0.3306, Val Loss: 0.4800
# Epoch  67/250 - Train Acc: 0.9274, Val Acc: 0.8272, Train Loss: 0.3278, Val Loss: 0.4780
# Epoch  68/250 - Train Acc: 0.9285, Val Acc: 0.8296, Train Loss: 0.3244, Val Loss: 0.4757
# Epoch  69/250 - Train Acc: 0.9297, Val Acc: 0.8260, Train Loss: 0.3214, Val Loss: 0.4744
# Epoch  70/250 - Train Acc: 0.9305, Val Acc: 0.8272, Train Loss: 0.3190, Val Loss: 0.4732
# Epoch  71/250 - Train Acc: 0.9313, Val Acc: 0.8272, Train Loss: 0.3166, Val Loss: 0.4719
# Epoch  72/250 - Train Acc: 0.9313, Val Acc: 0.8260, Train Loss: 0.3139, Val Loss: 0.4708
# Epoch  73/250 - Train Acc: 0.9343, Val Acc: 0.8284, Train Loss: 0.3111, Val Loss: 0.4690
# Epoch  74/250 - Train Acc: 0.9356, Val Acc: 0.8296, Train Loss: 0.3085, Val Loss: 0.4675
# Epoch  75/250 - Train Acc: 0.9358, Val Acc: 0.8308, Train Loss: 0.3050, Val Loss: 0.4666
# Epoch  76/250 - Train Acc: 0.9368, Val Acc: 0.8284, Train Loss: 0.3020, Val Loss: 0.4645
# Epoch  77/250 - Train Acc: 0.9376, Val Acc: 0.8284, Train Loss: 0.2998, Val Loss: 0.4635
# Epoch  78/250 - Train Acc: 0.9391, Val Acc: 0.8296, Train Loss: 0.2968, Val Loss: 0.4618
# Epoch  79/250 - Train Acc: 0.9386, Val Acc: 0.8284, Train Loss: 0.2944, Val Loss: 0.4604
# Epoch  80/250 - Train Acc: 0.9394, Val Acc: 0.8272, Train Loss: 0.2913, Val Loss: 0.4591
# Epoch  81/250 - Train Acc: 0.9404, Val Acc: 0.8296, Train Loss: 0.2887, Val Loss: 0.4577
# Epoch  82/250 - Train Acc: 0.9422, Val Acc: 0.8296, Train Loss: 0.2862, Val Loss: 0.4567
# Epoch  83/250 - Train Acc: 0.9429, Val Acc: 0.8284, Train Loss: 0.2840, Val Loss: 0.4551
# Epoch  84/250 - Train Acc: 0.9437, Val Acc: 0.8284, Train Loss: 0.2823, Val Loss: 0.4543
# Epoch  85/250 - Train Acc: 0.9442, Val Acc: 0.8284, Train Loss: 0.2805, Val Loss: 0.4531
# Epoch  86/250 - Train Acc: 0.9457, Val Acc: 0.8284, Train Loss: 0.2778, Val Loss: 0.4519
# Epoch  87/250 - Train Acc: 0.9472, Val Acc: 0.8272, Train Loss: 0.2756, Val Loss: 0.4513
# Epoch  88/250 - Train Acc: 0.9475, Val Acc: 0.8296, Train Loss: 0.2737, Val Loss: 0.4505
# Epoch  89/250 - Train Acc: 0.9493, Val Acc: 0.8272, Train Loss: 0.2714, Val Loss: 0.4494
# Epoch  90/250 - Train Acc: 0.9498, Val Acc: 0.8284, Train Loss: 0.2694, Val Loss: 0.4485
# Epoch  91/250 - Train Acc: 0.9498, Val Acc: 0.8284, Train Loss: 0.2673, Val Loss: 0.4479
# Epoch  92/250 - Train Acc: 0.9500, Val Acc: 0.8260, Train Loss: 0.2649, Val Loss: 0.4472
# Epoch  93/250 - Train Acc: 0.9508, Val Acc: 0.8284, Train Loss: 0.2618, Val Loss: 0.4452
# Epoch  94/250 - Train Acc: 0.9521, Val Acc: 0.8296, Train Loss: 0.2596, Val Loss: 0.4437
# Epoch  95/250 - Train Acc: 0.9536, Val Acc: 0.8284, Train Loss: 0.2567, Val Loss: 0.4427
# Epoch  96/250 - Train Acc: 0.9548, Val Acc: 0.8296, Train Loss: 0.2548, Val Loss: 0.4417
# Epoch  97/250 - Train Acc: 0.9556, Val Acc: 0.8308, Train Loss: 0.2524, Val Loss: 0.4407
# Epoch  98/250 - Train Acc: 0.9559, Val Acc: 0.8284, Train Loss: 0.2507, Val Loss: 0.4407
# Epoch  99/250 - Train Acc: 0.9561, Val Acc: 0.8308, Train Loss: 0.2492, Val Loss: 0.4398
# Epoch 100/250 - Train Acc: 0.9569, Val Acc: 0.8320, Train Loss: 0.2474, Val Loss: 0.4386
# Epoch 101/250 - Train Acc: 0.9574, Val Acc: 0.8308, Train Loss: 0.2454, Val Loss: 0.4383
# Epoch 102/250 - Train Acc: 0.9579, Val Acc: 0.8296, Train Loss: 0.2433, Val Loss: 0.4376
# Epoch 103/250 - Train Acc: 0.9584, Val Acc: 0.8308, Train Loss: 0.2421, Val Loss: 0.4368
# Epoch 104/250 - Train Acc: 0.9587, Val Acc: 0.8343, Train Loss: 0.2404, Val Loss: 0.4358
# Epoch 105/250 - Train Acc: 0.9589, Val Acc: 0.8308, Train Loss: 0.2391, Val Loss: 0.4354
# Epoch 106/250 - Train Acc: 0.9604, Val Acc: 0.8343, Train Loss: 0.2372, Val Loss: 0.4355
# Epoch 107/250 - Train Acc: 0.9609, Val Acc: 0.8367, Train Loss: 0.2355, Val Loss: 0.4346
# Epoch 108/250 - Train Acc: 0.9612, Val Acc: 0.8379, Train Loss: 0.2339, Val Loss: 0.4345
# Epoch 109/250 - Train Acc: 0.9617, Val Acc: 0.8379, Train Loss: 0.2316, Val Loss: 0.4344
# Epoch 110/250 - Train Acc: 0.9625, Val Acc: 0.8379, Train Loss: 0.2297, Val Loss: 0.4334
# Epoch 111/250 - Train Acc: 0.9630, Val Acc: 0.8379, Train Loss: 0.2276, Val Loss: 0.4329
# Epoch 112/250 - Train Acc: 0.9632, Val Acc: 0.8367, Train Loss: 0.2259, Val Loss: 0.4323
# Epoch 113/250 - Train Acc: 0.9642, Val Acc: 0.8367, Train Loss: 0.2242, Val Loss: 0.4320
# Epoch 114/250 - Train Acc: 0.9642, Val Acc: 0.8379, Train Loss: 0.2224, Val Loss: 0.4316
# Epoch 115/250 - Train Acc: 0.9655, Val Acc: 0.8414, Train Loss: 0.2211, Val Loss: 0.4311
# Epoch 116/250 - Train Acc: 0.9658, Val Acc: 0.8438, Train Loss: 0.2190, Val Loss: 0.4296
# Epoch 117/250 - Train Acc: 0.9663, Val Acc: 0.8485, Train Loss: 0.2168, Val Loss: 0.4296
# Epoch 118/250 - Train Acc: 0.9665, Val Acc: 0.8462, Train Loss: 0.2149, Val Loss: 0.4294
# Epoch 119/250 - Train Acc: 0.9665, Val Acc: 0.8485, Train Loss: 0.2133, Val Loss: 0.4294
# Epoch 120/250 - Train Acc: 0.9670, Val Acc: 0.8462, Train Loss: 0.2118, Val Loss: 0.4282
# Epoch 121/250 - Train Acc: 0.9668, Val Acc: 0.8497, Train Loss: 0.2106, Val Loss: 0.4273
# Epoch 122/250 - Train Acc: 0.9673, Val Acc: 0.8462, Train Loss: 0.2091, Val Loss: 0.4276
# Epoch 123/250 - Train Acc: 0.9673, Val Acc: 0.8450, Train Loss: 0.2072, Val Loss: 0.4277
# Epoch 124/250 - Train Acc: 0.9678, Val Acc: 0.8462, Train Loss: 0.2062, Val Loss: 0.4268
# Epoch 125/250 - Train Acc: 0.9680, Val Acc: 0.8438, Train Loss: 0.2051, Val Loss: 0.4267
# Epoch 126/250 - Train Acc: 0.9683, Val Acc: 0.8438, Train Loss: 0.2036, Val Loss: 0.4259
# Epoch 127/250 - Train Acc: 0.9696, Val Acc: 0.8414, Train Loss: 0.2016, Val Loss: 0.4256
# Epoch 128/250 - Train Acc: 0.9698, Val Acc: 0.8438, Train Loss: 0.1998, Val Loss: 0.4255
# Epoch 129/250 - Train Acc: 0.9706, Val Acc: 0.8426, Train Loss: 0.1981, Val Loss: 0.4248
# Epoch 130/250 - Train Acc: 0.9713, Val Acc: 0.8414, Train Loss: 0.1970, Val Loss: 0.4243
# Epoch 131/250 - Train Acc: 0.9713, Val Acc: 0.8414, Train Loss: 0.1954, Val Loss: 0.4246
# Epoch 132/250 - Train Acc: 0.9718, Val Acc: 0.8391, Train Loss: 0.1940, Val Loss: 0.4241
# Epoch 133/250 - Train Acc: 0.9723, Val Acc: 0.8402, Train Loss: 0.1927, Val Loss: 0.4240
# Epoch 134/250 - Train Acc: 0.9723, Val Acc: 0.8426, Train Loss: 0.1917, Val Loss: 0.4235
# Epoch 135/250 - Train Acc: 0.9736, Val Acc: 0.8426, Train Loss: 0.1896, Val Loss: 0.4233
# Epoch 136/250 - Train Acc: 0.9744, Val Acc: 0.8426, Train Loss: 0.1877, Val Loss: 0.4243
# Epoch 137/250 - Train Acc: 0.9744, Val Acc: 0.8426, Train Loss: 0.1868, Val Loss: 0.4240
# Epoch 138/250 - Train Acc: 0.9741, Val Acc: 0.8426, Train Loss: 0.1854, Val Loss: 0.4239
# Epoch 139/250 - Train Acc: 0.9749, Val Acc: 0.8426, Train Loss: 0.1840, Val Loss: 0.4237
# Epoch 140/250 - Train Acc: 0.9754, Val Acc: 0.8462, Train Loss: 0.1822, Val Loss: 0.4240
# Epoch 141/250 - Train Acc: 0.9764, Val Acc: 0.8438, Train Loss: 0.1810, Val Loss: 0.4238
# Epoch 142/250 - Train Acc: 0.9769, Val Acc: 0.8450, Train Loss: 0.1797, Val Loss: 0.4232
# Epoch 143/250 - Train Acc: 0.9774, Val Acc: 0.8450, Train Loss: 0.1787, Val Loss: 0.4223
# Epoch 144/250 - Train Acc: 0.9784, Val Acc: 0.8426, Train Loss: 0.1776, Val Loss: 0.4219
# Epoch 145/250 - Train Acc: 0.9774, Val Acc: 0.8462, Train Loss: 0.1761, Val Loss: 0.4206
# Epoch 146/250 - Train Acc: 0.9787, Val Acc: 0.8438, Train Loss: 0.1748, Val Loss: 0.4204
# Epoch 147/250 - Train Acc: 0.9792, Val Acc: 0.8438, Train Loss: 0.1735, Val Loss: 0.4208
# Epoch 148/250 - Train Acc: 0.9797, Val Acc: 0.8426, Train Loss: 0.1722, Val Loss: 0.4205
# Epoch 149/250 - Train Acc: 0.9800, Val Acc: 0.8426, Train Loss: 0.1709, Val Loss: 0.4202
# Epoch 150/250 - Train Acc: 0.9810, Val Acc: 0.8414, Train Loss: 0.1698, Val Loss: 0.4202
# Epoch 151/250 - Train Acc: 0.9810, Val Acc: 0.8402, Train Loss: 0.1686, Val Loss: 0.4207
# Epoch 152/250 - Train Acc: 0.9822, Val Acc: 0.8414, Train Loss: 0.1675, Val Loss: 0.4202
# Epoch 153/250 - Train Acc: 0.9833, Val Acc: 0.8414, Train Loss: 0.1660, Val Loss: 0.4206
# Epoch 154/250 - Train Acc: 0.9833, Val Acc: 0.8402, Train Loss: 0.1651, Val Loss: 0.4204
# Epoch 155/250 - Train Acc: 0.9830, Val Acc: 0.8391, Train Loss: 0.1641, Val Loss: 0.4206
# Epoch 156/250 - Train Acc: 0.9838, Val Acc: 0.8402, Train Loss: 0.1632, Val Loss: 0.4209
# Epoch 157/250 - Train Acc: 0.9835, Val Acc: 0.8414, Train Loss: 0.1619, Val Loss: 0.4204
# Epoch 158/250 - Train Acc: 0.9838, Val Acc: 0.8391, Train Loss: 0.1610, Val Loss: 0.4206
# Epoch 159/250 - Train Acc: 0.9843, Val Acc: 0.8414, Train Loss: 0.1598, Val Loss: 0.4200
# Epoch 160/250 - Train Acc: 0.9850, Val Acc: 0.8379, Train Loss: 0.1586, Val Loss: 0.4202
# Epoch 161/250 - Train Acc: 0.9853, Val Acc: 0.8402, Train Loss: 0.1573, Val Loss: 0.4197
# Epoch 162/250 - Train Acc: 0.9855, Val Acc: 0.8391, Train Loss: 0.1562, Val Loss: 0.4201
# Epoch 163/250 - Train Acc: 0.9858, Val Acc: 0.8367, Train Loss: 0.1552, Val Loss: 0.4200
# Epoch 164/250 - Train Acc: 0.9855, Val Acc: 0.8367, Train Loss: 0.1541, Val Loss: 0.4197
# Epoch 165/250 - Train Acc: 0.9858, Val Acc: 0.8391, Train Loss: 0.1534, Val Loss: 0.4191
# Epoch 166/250 - Train Acc: 0.9860, Val Acc: 0.8367, Train Loss: 0.1523, Val Loss: 0.4194
# Epoch 167/250 - Train Acc: 0.9863, Val Acc: 0.8367, Train Loss: 0.1514, Val Loss: 0.4191
# Epoch 168/250 - Train Acc: 0.9866, Val Acc: 0.8355, Train Loss: 0.1505, Val Loss: 0.4190
# Epoch 169/250 - Train Acc: 0.9873, Val Acc: 0.8367, Train Loss: 0.1491, Val Loss: 0.4187
# Epoch 170/250 - Train Acc: 0.9876, Val Acc: 0.8402, Train Loss: 0.1482, Val Loss: 0.4185
# Epoch 171/250 - Train Acc: 0.9881, Val Acc: 0.8426, Train Loss: 0.1469, Val Loss: 0.4185
# Epoch 172/250 - Train Acc: 0.9881, Val Acc: 0.8402, Train Loss: 0.1461, Val Loss: 0.4184
# Epoch 173/250 - Train Acc: 0.9881, Val Acc: 0.8391, Train Loss: 0.1450, Val Loss: 0.4180
# Epoch 174/250 - Train Acc: 0.9886, Val Acc: 0.8391, Train Loss: 0.1441, Val Loss: 0.4185
# Epoch 175/250 - Train Acc: 0.9893, Val Acc: 0.8391, Train Loss: 0.1427, Val Loss: 0.4192
# Epoch 176/250 - Train Acc: 0.9896, Val Acc: 0.8426, Train Loss: 0.1417, Val Loss: 0.4190
# Epoch 177/250 - Train Acc: 0.9896, Val Acc: 0.8402, Train Loss: 0.1410, Val Loss: 0.4187
# Epoch 178/250 - Train Acc: 0.9901, Val Acc: 0.8426, Train Loss: 0.1401, Val Loss: 0.4186
# Epoch 179/250 - Train Acc: 0.9901, Val Acc: 0.8367, Train Loss: 0.1388, Val Loss: 0.4191
# Epoch 180/250 - Train Acc: 0.9899, Val Acc: 0.8391, Train Loss: 0.1381, Val Loss: 0.4192
# Epoch 181/250 - Train Acc: 0.9901, Val Acc: 0.8391, Train Loss: 0.1373, Val Loss: 0.4185
# Epoch 182/250 - Train Acc: 0.9906, Val Acc: 0.8402, Train Loss: 0.1364, Val Loss: 0.4189
# Epoch 183/250 - Train Acc: 0.9906, Val Acc: 0.8379, Train Loss: 0.1357, Val Loss: 0.4183
# Epoch 184/250 - Train Acc: 0.9906, Val Acc: 0.8367, Train Loss: 0.1347, Val Loss: 0.4182
# Epoch 185/250 - Train Acc: 0.9909, Val Acc: 0.8367, Train Loss: 0.1337, Val Loss: 0.4182
# Epoch 186/250 - Train Acc: 0.9909, Val Acc: 0.8402, Train Loss: 0.1327, Val Loss: 0.4182
# Epoch 187/250 - Train Acc: 0.9906, Val Acc: 0.8379, Train Loss: 0.1317, Val Loss: 0.4186
# Epoch 188/250 - Train Acc: 0.9909, Val Acc: 0.8379, Train Loss: 0.1308, Val Loss: 0.4176
# Epoch 189/250 - Train Acc: 0.9909, Val Acc: 0.8379, Train Loss: 0.1298, Val Loss: 0.4174
# Epoch 190/250 - Train Acc: 0.9911, Val Acc: 0.8367, Train Loss: 0.1291, Val Loss: 0.4172
# Epoch 191/250 - Train Acc: 0.9914, Val Acc: 0.8379, Train Loss: 0.1280, Val Loss: 0.4169
# Epoch 192/250 - Train Acc: 0.9916, Val Acc: 0.8379, Train Loss: 0.1270, Val Loss: 0.4170
# Epoch 193/250 - Train Acc: 0.9919, Val Acc: 0.8414, Train Loss: 0.1262, Val Loss: 0.4168
# Epoch 194/250 - Train Acc: 0.9919, Val Acc: 0.8414, Train Loss: 0.1253, Val Loss: 0.4167
# Epoch 195/250 - Train Acc: 0.9924, Val Acc: 0.8414, Train Loss: 0.1245, Val Loss: 0.4165
# Epoch 196/250 - Train Acc: 0.9924, Val Acc: 0.8402, Train Loss: 0.1235, Val Loss: 0.4163
# Epoch 197/250 - Train Acc: 0.9929, Val Acc: 0.8402, Train Loss: 0.1225, Val Loss: 0.4157
# Epoch 198/250 - Train Acc: 0.9934, Val Acc: 0.8391, Train Loss: 0.1217, Val Loss: 0.4158
# Epoch 199/250 - Train Acc: 0.9939, Val Acc: 0.8402, Train Loss: 0.1210, Val Loss: 0.4159
# Epoch 200/250 - Train Acc: 0.9942, Val Acc: 0.8379, Train Loss: 0.1204, Val Loss: 0.4159
# Epoch 201/250 - Train Acc: 0.9939, Val Acc: 0.8391, Train Loss: 0.1194, Val Loss: 0.4164
# Epoch 202/250 - Train Acc: 0.9939, Val Acc: 0.8379, Train Loss: 0.1188, Val Loss: 0.4166
# Epoch 203/250 - Train Acc: 0.9939, Val Acc: 0.8367, Train Loss: 0.1179, Val Loss: 0.4166
# Epoch 204/250 - Train Acc: 0.9942, Val Acc: 0.8367, Train Loss: 0.1174, Val Loss: 0.4173
# Epoch 205/250 - Train Acc: 0.9942, Val Acc: 0.8343, Train Loss: 0.1166, Val Loss: 0.4172
# Epoch 206/250 - Train Acc: 0.9942, Val Acc: 0.8343, Train Loss: 0.1159, Val Loss: 0.4172
# Epoch 207/250 - Train Acc: 0.9939, Val Acc: 0.8355, Train Loss: 0.1154, Val Loss: 0.4177
# Epoch 208/250 - Train Acc: 0.9939, Val Acc: 0.8343, Train Loss: 0.1145, Val Loss: 0.4179
# Epoch 209/250 - Train Acc: 0.9942, Val Acc: 0.8367, Train Loss: 0.1137, Val Loss: 0.4180
# Epoch 210/250 - Train Acc: 0.9942, Val Acc: 0.8355, Train Loss: 0.1131, Val Loss: 0.4176
# Epoch 211/250 - Train Acc: 0.9942, Val Acc: 0.8367, Train Loss: 0.1127, Val Loss: 0.4173
# Epoch 212/250 - Train Acc: 0.9942, Val Acc: 0.8355, Train Loss: 0.1120, Val Loss: 0.4175
# Epoch 213/250 - Train Acc: 0.9944, Val Acc: 0.8355, Train Loss: 0.1113, Val Loss: 0.4181
# Epoch 214/250 - Train Acc: 0.9944, Val Acc: 0.8343, Train Loss: 0.1107, Val Loss: 0.4183
# Epoch 215/250 - Train Acc: 0.9947, Val Acc: 0.8331, Train Loss: 0.1101, Val Loss: 0.4182
# Epoch 216/250 - Train Acc: 0.9952, Val Acc: 0.8331, Train Loss: 0.1092, Val Loss: 0.4182
# Epoch 217/250 - Train Acc: 0.9949, Val Acc: 0.8343, Train Loss: 0.1088, Val Loss: 0.4184
# Epoch 218/250 - Train Acc: 0.9954, Val Acc: 0.8343, Train Loss: 0.1078, Val Loss: 0.4184
# Epoch 219/250 - Train Acc: 0.9959, Val Acc: 0.8343, Train Loss: 0.1071, Val Loss: 0.4183
# Epoch 220/250 - Train Acc: 0.9959, Val Acc: 0.8367, Train Loss: 0.1063, Val Loss: 0.4184
# Epoch 221/250 - Train Acc: 0.9962, Val Acc: 0.8367, Train Loss: 0.1053, Val Loss: 0.4183
# Epoch 222/250 - Train Acc: 0.9962, Val Acc: 0.8367, Train Loss: 0.1048, Val Loss: 0.4182
# Epoch 223/250 - Train Acc: 0.9964, Val Acc: 0.8391, Train Loss: 0.1040, Val Loss: 0.4185
# Epoch 224/250 - Train Acc: 0.9964, Val Acc: 0.8379, Train Loss: 0.1031, Val Loss: 0.4184
# Epoch 225/250 - Train Acc: 0.9964, Val Acc: 0.8379, Train Loss: 0.1027, Val Loss: 0.4183
# Epoch 226/250 - Train Acc: 0.9964, Val Acc: 0.8391, Train Loss: 0.1020, Val Loss: 0.4186
# Epoch 227/250 - Train Acc: 0.9967, Val Acc: 0.8379, Train Loss: 0.1012, Val Loss: 0.4187
# Epoch 228/250 - Train Acc: 0.9967, Val Acc: 0.8355, Train Loss: 0.1006, Val Loss: 0.4188
# Epoch 229/250 - Train Acc: 0.9967, Val Acc: 0.8379, Train Loss: 0.0999, Val Loss: 0.4188
# Epoch 230/250 - Train Acc: 0.9970, Val Acc: 0.8391, Train Loss: 0.0992, Val Loss: 0.4185
# Epoch 231/250 - Train Acc: 0.9972, Val Acc: 0.8343, Train Loss: 0.0983, Val Loss: 0.4187
# Epoch 232/250 - Train Acc: 0.9975, Val Acc: 0.8320, Train Loss: 0.0976, Val Loss: 0.4191
# Epoch 233/250 - Train Acc: 0.9972, Val Acc: 0.8343, Train Loss: 0.0970, Val Loss: 0.4197
# Epoch 234/250 - Train Acc: 0.9975, Val Acc: 0.8343, Train Loss: 0.0965, Val Loss: 0.4196
# Epoch 235/250 - Train Acc: 0.9975, Val Acc: 0.8331, Train Loss: 0.0962, Val Loss: 0.4197
# Epoch 236/250 - Train Acc: 0.9977, Val Acc: 0.8331, Train Loss: 0.0956, Val Loss: 0.4197
# Epoch 237/250 - Train Acc: 0.9982, Val Acc: 0.8343, Train Loss: 0.0948, Val Loss: 0.4194
# Epoch 238/250 - Train Acc: 0.9982, Val Acc: 0.8331, Train Loss: 0.0942, Val Loss: 0.4196
# Epoch 239/250 - Train Acc: 0.9985, Val Acc: 0.8320, Train Loss: 0.0936, Val Loss: 0.4200
# Epoch 240/250 - Train Acc: 0.9985, Val Acc: 0.8331, Train Loss: 0.0929, Val Loss: 0.4205
# Epoch 241/250 - Train Acc: 0.9985, Val Acc: 0.8343, Train Loss: 0.0924, Val Loss: 0.4205
# Epoch 242/250 - Train Acc: 0.9985, Val Acc: 0.8320, Train Loss: 0.0920, Val Loss: 0.4204
# Epoch 243/250 - Train Acc: 0.9985, Val Acc: 0.8343, Train Loss: 0.0916, Val Loss: 0.4202
# Epoch 244/250 - Train Acc: 0.9985, Val Acc: 0.8308, Train Loss: 0.0911, Val Loss: 0.4208
# Epoch 245/250 - Train Acc: 0.9985, Val Acc: 0.8308, Train Loss: 0.0907, Val Loss: 0.4209
# Epoch 246/250 - Train Acc: 0.9985, Val Acc: 0.8331, Train Loss: 0.0902, Val Loss: 0.4207
# Epoch 247/250 - Train Acc: 0.9985, Val Acc: 0.8331, Train Loss: 0.0898, Val Loss: 0.4211
# Early stopping at epoch 247
# Training completed.
#
# ✅ Training complete! Best iteration: 247
#
# ✅ Step 5 Complete: Model training with real-time display finished!

# %%
# ============================================================================
# STEP 6: PLOT TRAINING PROGRESS ANALYSIS
# ============================================================================

def plot_training_progress_analysis(training_history):
    """Plot training progress with loss and accuracy curves"""

    # Set up the figure with subplots
    fig = plt.figure(figsize=(16, 6))

    # Add main title
    fig.suptitle('Training Progress Analysis', fontsize=16, fontweight='bold', y=0.98)

    # Create subplots
    ax1 = plt.subplot(1, 2, 1)  # Loss plot
    ax2 = plt.subplot(1, 2, 2)  # Accuracy plot

    # Plot 1: Model Loss Over Training
    ax1.plot(training_history['epochs'], training_history['train_loss'],
             'b-', linewidth=2.5, label='Training Loss')
    ax1.plot(training_history['epochs'], training_history['val_loss'],
             'r-', linewidth=2.5, label='Validation Loss')

    ax1.set_title('Model Loss Over Training', fontsize=14, fontweight='bold', pad=15)
    ax1.set_xlabel('Iteration', fontsize=12)
    ax1.set_ylabel('Multi-class Log Loss', fontsize=12)
    ax1.legend(fontsize=11, loc='upper right')
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim(0, max(training_history['epochs']))

    # Plot 2: Model Accuracy Over Training
    ax2.plot(training_history['epochs'], training_history['train_acc'],
             'b-', linewidth=2.5, label='Training Accuracy')
    ax2.plot(training_history['epochs'], training_history['val_acc'],
             'orange', linewidth=2.5, label='Validation Accuracy')

    ax2.set_title('Model Accuracy Over Training', fontsize=14, fontweight='bold', pad=15)
    ax2.set_xlabel('Iteration', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.legend(fontsize=11, loc='lower right')
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim(0, max(training_history['epochs']))
    ax2.set_ylim(0, 1)

    # Adjust layout
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

    # Print training progress summary
    print(f"\n📊 Training Progress Summary:")
    print(f"- Total epochs trained: {len(training_history['epochs'])}")
    print(f"- Final training loss: {training_history['train_loss'][-1]:.4f}")
    print(f"- Final validation loss: {training_history['val_loss'][-1]:.4f}")
    print(f"- Final training accuracy: {training_history['train_acc'][-1]:.4f}")
    print(f"- Final validation accuracy: {training_history['val_acc'][-1]:.4f}")
    print(f"- Best iteration (early stopping): {training_history.get('best_iteration', 'N/A')}")

print("📈 Generating training progress visualizations...")
plot_training_progress_analysis(training_history)

print("\n✅ Step 6 Complete: Training progress analysis plotted!")
# Out:
# 📈 Generating training progress visualizations...
# 📊 Training Progress Summary:
# - Total epochs trained: 247
# - Final training loss: 0.0898
# - Final validation loss: 0.4211
# - Final training accuracy: 0.9985
# - Final validation accuracy: 0.8331
# - Best iteration (early stopping): 247
#
# ✅ Step 6 Complete: Training progress analysis plotted!

# %%
# ============================================================================
# STEP 7: EVALUATE MODEL AND CALCULATE ALL METRICS
# ============================================================================

def calculate_all_metrics(model, X, y, dataset_name):
    """Calculate comprehensive metrics"""
    y_pred = model.predict(X)

    # Calculate all required metrics
    accuracy = accuracy_score(y, y_pred)
    precision = precision_score(y, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y, y_pred, average='weighted', zero_division=0)
    f1_weighted = f1_score(y, y_pred, average='weighted', zero_division=0)
    f1_macro = f1_score(y, y_pred, average='macro', zero_division=0)

    metrics = {
        'Dataset': dataset_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score (Weighted Avg)': f1_weighted,
        'Macro F1 Score': f1_macro
    }

    return metrics, y_pred

print("📊 Evaluating model on all datasets...")

# Evaluate on training set
train_metrics, train_pred = calculate_all_metrics(model, X_train.values, y_train_encoded, "Training")

# Evaluate on validation set
val_metrics, val_pred = calculate_all_metrics(model, X_val.values, y_val_encoded, "Validation")

# Evaluate on test set
test_metrics, test_pred = calculate_all_metrics(model, X_test.values, y_test_encoded, "Test")

# Create results summary
results_df = pd.DataFrame([train_metrics, val_metrics, test_metrics])

print("\n🎯 MODEL EVALUATION RESULTS:")
print("="*80)
print(results_df.round(4).to_string(index=False))
print("="*80)

print("\n✅ Step 7 Complete: Model evaluation finished!")
# Out:
# 📊 Evaluating model on all datasets...
#
# 🎯 MODEL EVALUATION RESULTS:
# ================================================================================
#    Dataset  Accuracy  Precision  Recall  F1 Score (Weighted Avg)  Macro F1 Score
#   Training    0.9929     0.9929  0.9929                   0.9929          0.9929
# Validation    0.8402     0.8435  0.8402                   0.8411          0.8381
#       Test    0.8367     0.8421  0.8367                   0.8384          0.8378
# ================================================================================
#
# ✅ Step 7 Complete: Model evaluation finished!

# %%
# ============================================================================
# STEP 8: PLOT CONFUSION MATRICES
# ============================================================================

def plot_confusion_matrix(y_true, y_pred, dataset_name, class_names):
    """Plot confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
               xticklabels=class_names,
               yticklabels=class_names,
               cbar_kws={'label': 'Number of Samples'})

    plt.title(f'Confusion Matrix - {dataset_name}', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
    plt.ylabel('True Label', fontsize=12, fontweight='bold')

    # Add accuracy to the plot
    accuracy = accuracy_score(y_true, y_pred)
    plt.text(0.02, 0.98, f'Accuracy: {accuracy:.3f}',
             transform=plt.gca().transAxes, fontsize=8,
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

    plt.tight_layout()
    plt.show()

print("📈 Plotting confusion matrices...")

class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

# Plot confusion matrix for validation set
plot_confusion_matrix(y_val_encoded, val_pred, "Validation Set", class_names)

# Plot confusion matrix for test set
plot_confusion_matrix(y_test_encoded, test_pred, "Test Set", class_names)

print("\n✅ Step 8 Complete: Confusion matrices plotted!")
# Out:
# 📈 Plotting confusion matrices...
# ✅ Step 8 Complete: Confusion matrices plotted!

# %%
# ============================================================================
# STEP 9: DETAILED CLASSIFICATION REPORTS
# ============================================================================

print("📋 Generating detailed classification reports...")

print("\n" + "="*60)
print("DETAILED CLASSIFICATION REPORT - VALIDATION SET")
print("="*60)
val_report = classification_report(
    y_val_encoded, val_pred,
    target_names=class_names,
    zero_division=0
)
print(val_report)

print("\n" + "="*60)
print("DETAILED CLASSIFICATION REPORT - TEST SET")
print("="*60)
test_report = classification_report(
    y_test_encoded, test_pred,
    target_names=class_names,
    zero_division=0
)
print(test_report)

print("\n✅ Step 9 Complete: Classification reports generated!")
# Out:
# 📋 Generating detailed classification reports...
#
# ============================================================
# DETAILED CLASSIFICATION REPORT - VALIDATION SET
# ============================================================
#               precision    recall  f1-score   support
#
#     Very Low       0.74      0.75      0.75       160
#          Low       0.76      0.86      0.81       140
#       Medium       0.81      0.78      0.80       191
#         High       0.91      0.88      0.89       169
#    Very High       0.97      0.93      0.95       185
#
#     accuracy                           0.84       845
#    macro avg       0.84      0.84      0.84       845
# weighted avg       0.84      0.84      0.84       845
#
#
# ============================================================
# DETAILED CLASSIFICATION REPORT - TEST SET
# ============================================================
#               precision    recall  f1-score   support
#
#     Very Low       0.75      0.81      0.78       175
#          Low       0.79      0.84      0.82       158
#       Medium       0.77      0.77      0.77       167
#         High       0.95      0.86      0.90       173
#    Very High       0.94      0.90      0.92       172
#
#     accuracy                           0.84       845
#    macro avg       0.84      0.84      0.84       845
# weighted avg       0.84      0.84      0.84       845
#
#
# ✅ Step 9 Complete: Classification reports generated!

# %%
# ============================================================================
# STEP 10: FEATURE IMPORTANCE ANALYSIS
# ============================================================================

def plot_feature_importance(model, feature_names, top_n=20):
    """Plot top N most important features"""

    # Get feature importance
    importance = model.feature_importances_

    # Get top N features
    indices = np.argsort(importance)[::-1][:top_n]
    top_features = [feature_names[i] for i in indices]
    top_importance = importance[indices]

    # Create plot
    plt.figure(figsize=(12, 8))
    colors = plt.cm.viridis(np.linspace(0, 1, len(top_importance)))

    bars = plt.barh(range(len(top_importance)), top_importance[::-1], color=colors[::-1])
    plt.yticks(range(len(top_importance)), top_features[::-1])
    plt.xlabel('Importance Score', fontsize=12, fontweight='bold')
    plt.title(f'Top {top_n} Most Important Features', fontsize=16, fontweight='bold', pad=20)

    # Add value labels on bars
    for i, (bar, val) in enumerate(zip(bars, top_importance[::-1])):
        plt.text(val + 0.001, bar.get_y() + bar.get_height()/2,
                f'{val:.3f}', ha='left', va='center', fontsize=9)

    plt.tight_layout()
    plt.show()

    # Print top 10 features
    print(f"\n🏆 Top 10 Most Important Features:")
    for i, (feature, score) in enumerate(zip(top_features[:10], top_importance[:10])):
        print(f"{i+1:2d}. {feature:<40} {score:.4f}")

print("📊 Analyzing feature importance...")
plot_feature_importance(model, feature_names, top_n=20)

print("\n✅ Step 10 Complete: Feature importance analysis finished!")
# Out:
# 📊 Analyzing feature importance...
# 🏆 Top 10 Most Important Features:
#  1. Area (Acres)                             0.0510
#  2. Crop_Laushak                             0.0269
#  3. District_Barguna                         0.0254
#  4. Crop_Garlic                              0.0236
#  5. Crop_Beans                               0.0214
#  6. Crop_Cabbage                             0.0210
#  7. Crop_Onion                               0.0186
#  8. District_Satkhira                        0.0184
#  9. District_Manikganj                       0.0182
# 10. District_Lakshmipur                      0.0180
#
# ✅ Step 10 Complete: Feature importance analysis finished!

# %%
# ============================================================================
# STEP 11: FINAL SUMMARY AND KEY INSIGHTS
# ============================================================================

print("\n" + "="*80)
print("🎉 FINAL SUMMARY - XGBOOST CLASSIFICATION RESULTS")
print("="*80)

print("\n📊 PERFORMANCE METRICS SUMMARY:")
print("-" * 50)
for _, row in results_df.iterrows():
    print(f"{row['Dataset']:12} | Accuracy: {row['Accuracy']:.4f} | Macro F1: {row['Macro F1 Score']:.4f}")

print(f"\n🎯 KEY INSIGHTS:")
print(f"- Best performing dataset: {results_df.loc[results_df['Accuracy'].idxmax(), 'Dataset']}")
print(f"- Highest Macro F1 Score: {results_df['Macro F1 Score'].max():.4f}")
print(f"- Model converged at epoch: {training_history.get('best_iteration', len(training_history['epochs']))}")
print(f"- Total features used: {len(feature_names)}")
print(f"- Classes predicted: {len(class_names)}")

print(f"\n💡 RECOMMENDATIONS:")
if results_df.loc[2, 'Accuracy'] > 0.8:  # Test set accuracy
    print("✅ Model shows good performance on test data")
else:
    print("⚠️  Consider hyperparameter tuning or feature engineering")

if abs(results_df.loc[0, 'Accuracy'] - results_df.loc[1, 'Accuracy']) > 0.1:  # Train vs Val
    print("⚠️  Possible overfitting detected - consider regularization")
else:
    print("✅ Good generalization between training and validation")

print("\n🔧 MODEL CONFIGURATION USED:")
print("- Algorithm: XGBoost Classifier")
print("- Max Depth: 6")
print("- Learning Rate: 0.1")
print("- Subsample: 0.8")
print("- Column Sample: 0.8")
print("- Early Stopping: 50 rounds")
print("- Max Epochs: 250")

print("\n" + "="*80)
print("✅ ALL STEPS COMPLETED SUCCESSFULLY!")
print("Your XGBoost classification model is ready for production use!")
print("="*80)
# Out:
# ================================================================================
# 🎉 FINAL SUMMARY - XGBOOST CLASSIFICATION RESULTS
# ================================================================================
#
# 📊 PERFORMANCE METRICS SUMMARY:
# --------------------------------------------------
# Training     | Accuracy: 0.9929 | Macro F1: 0.9929
# Validation   | Accuracy: 0.8402 | Macro F1: 0.8381
# Test         | Accuracy: 0.8367 | Macro F1: 0.8378
#
# 🎯 KEY INSIGHTS:
# - Best performing dataset: Training
# - Highest Macro F1 Score: 0.9929
# - Model converged at epoch: 247
# - Total features used: 83
# - Classes predicted: 5
#
# 💡 RECOMMENDATIONS:
# ✅ Model shows good performance on test data
# ⚠️  Possible overfitting detected - consider regularization
#
# 🔧 MODEL CONFIGURATION USED:
# - Algorithm: XGBoost Classifier
# - Max Depth: 6
# - Learning Rate: 0.1
# - Subsample: 0.8
# - Column Sample: 0.8
# - Early Stopping: 50 rounds
# - Max Epochs: 250
#
# ================================================================================
# ✅ ALL STEPS COMPLETED SUCCESSFULLY!
# Your XGBoost classification model is ready for production use!
# ================================================================================
