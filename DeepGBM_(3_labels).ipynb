# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/thesis_2025/blob/main/DeepGBM_(3_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import lightgbm as lgb
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("✅ All libraries imported successfully!")
print("✅ Random seeds set for reproducibility!")
# Out:
# ✅ All libraries imported successfully!
# ✅ Random seeds set for reproducibility!

# %%
#==============================================================================
# Step 2: Define the DeepGBM Class
#==============================================================================

class DeepGBM:
    """
    Deep Gradient Boosting Machine combining LightGBM with Neural Networks
    """
    def __init__(self, n_classes=3, embedding_dim=16, hidden_units=[128, 64, 32]):
        self.n_classes = n_classes
        self.embedding_dim = embedding_dim
        self.hidden_units = hidden_units
        self.gbm_model = None
        self.nn_model = None
        self.scaler = StandardScaler()
        self.label_encoder = LabelEncoder()

    def create_quantile_labels(self, y):
        """Create quantile-based labels for production values (3 classes)"""
        quantiles = np.quantile(y, [0.33, 0.67])  # 33rd and 67th percentiles
        labels = []
        label_names = ['Low', 'Medium', 'High']

        for val in y:
            if val <= quantiles[0]:
                labels.append(0)  # Low
            elif val <= quantiles[1]:
                labels.append(1)  # Medium
            else:
                labels.append(2)  # High

        self.label_names = label_names
        self.quantiles = quantiles
        return np.array(labels)

    def add_noise_augmentation(self, X, y, noise_factor=0.01):
        """Add slight noise to training data for augmentation"""
        noise = np.random.normal(0, noise_factor, X.shape)
        X_augmented = X + noise
        return X_augmented, y

    def prepare_data(self, df, target_col='Production (M.Ton)', is_training=True, augment=False):
        """Prepare data for training/validation/testing"""
        # Separate features and target
        if target_col in df.columns:
            X = df.drop(columns=[target_col])
            y = df[target_col].values

            if is_training:
                # Create quantile-based labels
                y_labels = self.create_quantile_labels(y)
            else:
                # Apply existing quantiles for validation/test data
                y_labels = []
                for val in y:
                    if val <= self.quantiles[0]:
                        y_labels.append(0)  # Low
                    elif val <= self.quantiles[1]:
                        y_labels.append(1)  # Medium
                    else:
                        y_labels.append(2)  # High
                y_labels = np.array(y_labels)
        else:
            X = df
            y_labels = None

        # Handle missing values
        X = X.fillna(X.mean())

        # Scale features
        if is_training:
            X_scaled = self.scaler.fit_transform(X)
            # Apply data augmentation if requested
            if augment:
                X_scaled, y_labels = self.add_noise_augmentation(X_scaled, y_labels)
        else:
            X_scaled = self.scaler.transform(X)

        return X_scaled, y_labels, X.columns.tolist()

    def build_lightgbm(self, X_train, y_train, X_val, y_val):
        """Build and train LightGBM model"""
        # LightGBM parameters - Reduced complexity to prevent overfitting
        lgb_params = {
            'objective': 'multiclass',
            'num_class': self.n_classes,
            'metric': 'multi_logloss',
            'boosting_type': 'gbdt',
            'num_leaves': 15,  # Reduced from 31
            'learning_rate': 0.01,  # Reduced from 0.05
            'feature_fraction': 0.7,  # Reduced from 0.9
            'bagging_fraction': 0.7,  # Reduced from 0.8
            'bagging_freq': 3,  # Reduced from 5
            'lambda_l1': 0.1,  # Added L1 regularization
            'lambda_l2': 0.1,  # Added L2 regularization
            'min_data_in_leaf': 20,  # Added minimum samples per leaf
            'max_depth': 6,  # Limited tree depth
            'verbose': -1,
            'random_state': 42
        }

        # Create datasets
        train_data = lgb.Dataset(X_train, label=y_train)
        val_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

        # Train model with more conservative stopping
        self.gbm_model = lgb.train(
            lgb_params,
            train_data,
            valid_sets=[train_data, val_data],
            valid_names=['train', 'val'],
            num_boost_round=500,  # Reduced from 1000
            callbacks=[lgb.early_stopping(30), lgb.log_evaluation(0)]  # Earlier stopping
        )

        # Get GBM predictions as features for neural network
        gbm_train_pred = self.gbm_model.predict(X_train, num_iteration=self.gbm_model.best_iteration)
        gbm_val_pred = self.gbm_model.predict(X_val, num_iteration=self.gbm_model.best_iteration)

        return gbm_train_pred, gbm_val_pred

    def build_neural_network(self, input_dim, gbm_output_dim):
        """Build neural network that combines original features with GBM outputs"""
        # Input layers
        feature_input = layers.Input(shape=(input_dim,), name='features')
        gbm_input = layers.Input(shape=(gbm_output_dim,), name='gbm_output')

        # Feature processing branch - Reduced complexity
        x1 = layers.Dense(64, activation='relu')(feature_input)  # Reduced from 128
        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Dropout(0.5)(x1)  # Increased dropout from 0.3

        x1 = layers.Dense(32, activation='relu')(x1)  # Reduced from 64
        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Dropout(0.4)(x1)  # Increased dropout from 0.2

        # GBM output processing branch - Reduced complexity
        x2 = layers.Dense(16, activation='relu')(gbm_input)  # Reduced from 32
        x2 = layers.BatchNormalization()(x2)
        x2 = layers.Dropout(0.3)(x2)  # Increased dropout from 0.2

        # Combine branches
        combined = layers.Concatenate()([x1, x2])
        combined = layers.Dense(16, activation='relu')(combined)  # Reduced from 32
        combined = layers.BatchNormalization()(combined)
        combined = layers.Dropout(0.4)(combined)  # Increased dropout from 0.2

        # Output layer
        output = layers.Dense(self.n_classes, activation='softmax', name='output')(combined)

        # Create model
        model = keras.Model(inputs=[feature_input, gbm_input], outputs=output)

        # Compile model with L2 regularization
        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # Reduced learning rate
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        return model

    def fit(self, X_train, y_train, X_val, y_val, epochs=100, batch_size=32):
        """Train the DeepGBM model"""
        print("Training LightGBM...")
        gbm_train_pred, gbm_val_pred = self.build_lightgbm(X_train, y_train, X_val, y_val)

        print("Building Neural Network...")
        self.nn_model = self.build_neural_network(X_train.shape[1], gbm_train_pred.shape[1])

        print("Training Neural Network...")
        # Callbacks - More aggressive overfitting prevention
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss', patience=10, restore_best_weights=True  # Reduced patience
        )
        reduce_lr = keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.3, patience=5, min_lr=1e-7  # More aggressive LR reduction
        )

        # Train neural network
        history = self.nn_model.fit(
            [X_train, gbm_train_pred], y_train,
            validation_data=([X_val, gbm_val_pred], y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        return history

    def predict(self, X):
        """Make predictions using the trained DeepGBM model"""
        # Get GBM predictions
        gbm_pred = self.gbm_model.predict(X, num_iteration=self.gbm_model.best_iteration)

        # Get neural network predictions
        nn_pred = self.nn_model.predict([X, gbm_pred])

        return np.argmax(nn_pred, axis=1), nn_pred

    def predict_proba(self, X):
        """Get prediction probabilities"""
        gbm_pred = self.gbm_model.predict(X, num_iteration=self.gbm_model.best_iteration)
        nn_pred = self.nn_model.predict([X, gbm_pred])
        return nn_pred

print("✅ DeepGBM class defined successfully!")
# Out:
# ✅ DeepGBM class defined successfully!

# %%
#==============================================================================
# Step 3: Define utility functions
#==============================================================================

def load_and_preprocess_data():
    """Load and preprocess the CSV files"""
    try:
        train_df = pd.read_csv('/content/drive/MyDrive/UpdatedDataset/train.csv')
        val_df = pd.read_csv('/content/drive/MyDrive/UpdatedDataset/validation.csv')
        test_df = pd.read_csv('/content/drive/MyDrive/UpdatedDataset/test.csv')

        print(f"Train data shape: {train_df.shape}")
        print(f"Validation data shape: {val_df.shape}")
        print(f"Test data shape: {test_df.shape}")

        return train_df, val_df, test_df
    except FileNotFoundError as e:
        print(f"Error loading files: {e}")
        print("Please ensure train.csv, validation.csv, and test.csv are in the current directory")
        return None, None, None

def calculate_and_plot_metrics(y_true, y_pred, labels, title="Confusion Matrix"):
    """Calculate classification metrics and plot confusion matrix"""
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')
    f1_macro = f1_score(y_true, y_pred, average='macro')

    metrics = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1-Score (Weighted)': f1_weighted,
        'F1-Score (Macro)': f1_macro
    }

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5, 3))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()

    return metrics

def detect_overfitting(history, threshold=0.1):
    """Detect overfitting based on training history"""
    train_acc = history.history['accuracy'][-10:]  # Last 10 epochs
    val_acc = history.history['val_accuracy'][-10:]

    avg_train_acc = np.mean(train_acc)
    avg_val_acc = np.mean(val_acc)

    gap = avg_train_acc - avg_val_acc

    print(f"\n=== Overfitting Analysis ===")
    print(f"Average Training Accuracy (last 10 epochs): {avg_train_acc:.4f}")
    print(f"Average Validation Accuracy (last 10 epochs): {avg_val_acc:.4f}")
    print(f"Accuracy Gap: {gap:.4f}")

    if gap > threshold:
        print(f"⚠️  OVERFITTING DETECTED! Gap > {threshold}")
        print("Recommendations:")
        print("- Increase dropout rates")
        print("- Add more regularization")
        print("- Reduce model complexity")
        print("- Collect more training data")
        print("- Use data augmentation")
    else:
        print(f"✅ Model appears well-balanced (gap <= {threshold})")

    return gap > threshold

def plot_training_history(history, title_suffix=""):
    """Plot training history"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title(f'Model Accuracy {title_suffix}')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title(f'Model Loss {title_suffix}')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

print("✅ All utility functions defined successfully!")
# Out:
# ✅ All utility functions defined successfully!

# %%
#==============================================================================
# Step 4: Load and examine data
#==============================================================================

print("=== DeepGBM Agricultural Production Classification ===\n")

# Load data
train_df, val_df, test_df = load_and_preprocess_data()
if train_df is None:
    print("❌ Error: Could not load data files. Please check file paths.")
else:
    print("✅ Data loaded successfully!")
# Out:
# === DeepGBM Agricultural Production Classification ===
#
# Train data shape: (3942, 84)
# Validation data shape: (845, 84)
# Test data shape: (845, 84)
# ✅ Data loaded successfully!

# %%
#==============================================================================
# Step 5: Initialize model and prepare data
#==============================================================================

# Initialize model (3 classes)
model = DeepGBM(n_classes=3, embedding_dim=16, hidden_units=[128, 64, 32])
print("✅ DeepGBM model initialized!")

# Prepare training data
print("Preparing training data...")
X_train, y_train, feature_names = model.prepare_data(train_df, is_training=True)
print(f"✅ Training data prepared: {X_train.shape}")

# Prepare validation data
print("Preparing validation data...")
X_val, y_val, _ = model.prepare_data(val_df, is_training=False)
print(f"✅ Validation data prepared: {X_val.shape}")

# Prepare test data
print("Preparing test data...")
X_test, y_test, _ = model.prepare_data(test_df, is_training=False)
print(f"✅ Test data prepared: {X_test.shape}")

print(f"\nQuantile thresholds: {model.quantiles}")
print(f"Label distribution in training:")
unique, counts = np.unique(y_train, return_counts=True)
for i, (label, count) in enumerate(zip(unique, counts)):
    print(f"  {model.label_names[label]}: {count} samples")
# Out:
# ✅ DeepGBM model initialized!
# Preparing training data...
# ✅ Training data prepared: (3942, 83)
# Preparing validation data...
# ✅ Validation data prepared: (845, 83)
# Preparing test data...
# ✅ Test data prepared: (845, 83)
#
# Quantile thresholds: [1071.5565 4035.9099]
# Label distribution in training:
#   Low: 1301 samples
#   Medium: 1340 samples
#   High: 1301 samples

# %%
#==============================================================================
# Step 6: Train the model
#==============================================================================

print("\n=== Training DeepGBM Model ===")
history = model.fit(X_train, y_train, X_val, y_val, epochs=100, batch_size=32)
print("✅ Model training completed!")
# Out:
# === Training DeepGBM Model ===
# Training LightGBM...
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [500]	train's multi_logloss: 0.232639	val's multi_logloss: 0.295433
# Building Neural Network...
# Training Neural Network...
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3107 - loss: 1.7406 - val_accuracy: 0.4355 - val_loss: 1.0436 - learning_rate: 5.0000e-04
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5297 - loss: 1.0748 - val_accuracy: 0.7030 - val_loss: 0.7591 - learning_rate: 5.0000e-04
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7170 - loss: 0.7080 - val_accuracy: 0.8485 - val_loss: 0.4971 - learning_rate: 5.0000e-04
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7868 - loss: 0.5464 - val_accuracy: 0.8828 - val_loss: 0.3858 - learning_rate: 5.0000e-04
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8352 - loss: 0.4733 - val_accuracy: 0.8864 - val_loss: 0.3585 - learning_rate: 5.0000e-04
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8670 - loss: 0.4187 - val_accuracy: 0.8864 - val_loss: 0.3528 - learning_rate: 5.0000e-04
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8809 - loss: 0.3683 - val_accuracy: 0.8864 - val_loss: 0.3519 - learning_rate: 5.0000e-04
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8933 - loss: 0.3477 - val_accuracy: 0.8876 - val_loss: 0.3510 - learning_rate: 5.0000e-04
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8956 - loss: 0.3260 - val_accuracy: 0.8888 - val_loss: 0.3513 - learning_rate: 5.0000e-04
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8995 - loss: 0.3495 - val_accuracy: 0.8911 - val_loss: 0.3439 - learning_rate: 5.0000e-04
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8996 - loss: 0.3260 - val_accuracy: 0.8899 - val_loss: 0.3415 - learning_rate: 5.0000e-04
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9045 - loss: 0.3015 - val_accuracy: 0.8899 - val_loss: 0.3379 - learning_rate: 5.0000e-04
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9043 - loss: 0.3136 - val_accuracy: 0.8888 - val_loss: 0.3372 - learning_rate: 5.0000e-04
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9036 - loss: 0.2917 - val_accuracy: 0.8852 - val_loss: 0.3350 - learning_rate: 5.0000e-04
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9062 - loss: 0.2979 - val_accuracy: 0.8888 - val_loss: 0.3319 - learning_rate: 5.0000e-04
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9043 - loss: 0.3025 - val_accuracy: 0.8876 - val_loss: 0.3312 - learning_rate: 5.0000e-04
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9040 - loss: 0.3025 - val_accuracy: 0.8852 - val_loss: 0.3251 - learning_rate: 5.0000e-04
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9120 - loss: 0.2786 - val_accuracy: 0.8888 - val_loss: 0.3217 - learning_rate: 5.0000e-04
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9106 - loss: 0.2930 - val_accuracy: 0.8876 - val_loss: 0.3215 - learning_rate: 5.0000e-04
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9083 - loss: 0.2900 - val_accuracy: 0.8864 - val_loss: 0.3207 - learning_rate: 5.0000e-04
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9025 - loss: 0.2808 - val_accuracy: 0.8864 - val_loss: 0.3175 - learning_rate: 5.0000e-04
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9101 - loss: 0.2779 - val_accuracy: 0.8864 - val_loss: 0.3159 - learning_rate: 5.0000e-04
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9110 - loss: 0.2837 - val_accuracy: 0.8864 - val_loss: 0.3136 - learning_rate: 5.0000e-04
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9100 - loss: 0.2771 - val_accuracy: 0.8864 - val_loss: 0.3131 - learning_rate: 5.0000e-04
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9086 - loss: 0.2827 - val_accuracy: 0.8899 - val_loss: 0.3093 - learning_rate: 5.0000e-04
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9106 - loss: 0.2598 - val_accuracy: 0.8888 - val_loss: 0.3083 - learning_rate: 5.0000e-04
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9140 - loss: 0.2722 - val_accuracy: 0.8899 - val_loss: 0.3070 - learning_rate: 5.0000e-04
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9156 - loss: 0.2681 - val_accuracy: 0.8899 - val_loss: 0.3049 - learning_rate: 5.0000e-04
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9110 - loss: 0.2705 - val_accuracy: 0.8935 - val_loss: 0.3034 - learning_rate: 5.0000e-04
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9139 - loss: 0.2656 - val_accuracy: 0.8911 - val_loss: 0.3018 - learning_rate: 5.0000e-04
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9154 - loss: 0.2501 - val_accuracy: 0.8911 - val_loss: 0.3032 - learning_rate: 5.0000e-04
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9140 - loss: 0.2596 - val_accuracy: 0.8899 - val_loss: 0.3028 - learning_rate: 5.0000e-04
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9114 - loss: 0.2633 - val_accuracy: 0.8935 - val_loss: 0.3003 - learning_rate: 5.0000e-04
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9152 - loss: 0.2573 - val_accuracy: 0.8935 - val_loss: 0.2990 - learning_rate: 5.0000e-04
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9139 - loss: 0.2636 - val_accuracy: 0.8935 - val_loss: 0.2960 - learning_rate: 5.0000e-04
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9128 - loss: 0.2573 - val_accuracy: 0.8947 - val_loss: 0.2953 - learning_rate: 5.0000e-04
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9165 - loss: 0.2609 - val_accuracy: 0.8959 - val_loss: 0.2928 - learning_rate: 5.0000e-04
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9225 - loss: 0.2562 - val_accuracy: 0.8947 - val_loss: 0.2911 - learning_rate: 5.0000e-04
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9218 - loss: 0.2401 - val_accuracy: 0.8959 - val_loss: 0.2912 - learning_rate: 5.0000e-04
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9104 - loss: 0.2601 - val_accuracy: 0.8959 - val_loss: 0.2905 - learning_rate: 5.0000e-04
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9119 - loss: 0.2485 - val_accuracy: 0.8959 - val_loss: 0.2889 - learning_rate: 5.0000e-04
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9122 - loss: 0.2514 - val_accuracy: 0.8959 - val_loss: 0.2861 - learning_rate: 5.0000e-04
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9159 - loss: 0.2313 - val_accuracy: 0.8959 - val_loss: 0.2869 - learning_rate: 5.0000e-04
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9201 - loss: 0.2408 - val_accuracy: 0.8970 - val_loss: 0.2858 - learning_rate: 5.0000e-04
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9212 - loss: 0.2483 - val_accuracy: 0.8982 - val_loss: 0.2873 - learning_rate: 5.0000e-04
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9192 - loss: 0.2443 - val_accuracy: 0.9018 - val_loss: 0.2846 - learning_rate: 5.0000e-04
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9251 - loss: 0.2346 - val_accuracy: 0.9030 - val_loss: 0.2817 - learning_rate: 5.0000e-04
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9167 - loss: 0.2409 - val_accuracy: 0.9018 - val_loss: 0.2818 - learning_rate: 5.0000e-04
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9163 - loss: 0.2363 - val_accuracy: 0.9006 - val_loss: 0.2807 - learning_rate: 5.0000e-04
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9288 - loss: 0.2283 - val_accuracy: 0.8994 - val_loss: 0.2830 - learning_rate: 5.0000e-04
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9274 - loss: 0.2181 - val_accuracy: 0.8982 - val_loss: 0.2836 - learning_rate: 5.0000e-04
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9249 - loss: 0.2227 - val_accuracy: 0.8994 - val_loss: 0.2778 - learning_rate: 5.0000e-04
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9199 - loss: 0.2401 - val_accuracy: 0.9030 - val_loss: 0.2791 - learning_rate: 5.0000e-04
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9222 - loss: 0.2327 - val_accuracy: 0.9030 - val_loss: 0.2794 - learning_rate: 5.0000e-04
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9248 - loss: 0.2177 - val_accuracy: 0.8994 - val_loss: 0.2814 - learning_rate: 5.0000e-04
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9246 - loss: 0.2236 - val_accuracy: 0.9018 - val_loss: 0.2815 - learning_rate: 5.0000e-04
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9229 - loss: 0.2341 - val_accuracy: 0.9018 - val_loss: 0.2825 - learning_rate: 5.0000e-04
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9180 - loss: 0.2276 - val_accuracy: 0.9030 - val_loss: 0.2792 - learning_rate: 1.5000e-04
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9239 - loss: 0.2283 - val_accuracy: 0.9041 - val_loss: 0.2777 - learning_rate: 1.5000e-04
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9295 - loss: 0.2079 - val_accuracy: 0.9006 - val_loss: 0.2780 - learning_rate: 1.5000e-04
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9250 - loss: 0.2192 - val_accuracy: 0.9006 - val_loss: 0.2775 - learning_rate: 1.5000e-04
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9253 - loss: 0.2171 - val_accuracy: 0.9030 - val_loss: 0.2774 - learning_rate: 1.5000e-04
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9236 - loss: 0.2256 - val_accuracy: 0.9018 - val_loss: 0.2777 - learning_rate: 1.5000e-04
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9221 - loss: 0.2229 - val_accuracy: 0.9006 - val_loss: 0.2766 - learning_rate: 1.5000e-04
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9261 - loss: 0.2104 - val_accuracy: 0.9018 - val_loss: 0.2761 - learning_rate: 1.5000e-04
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9321 - loss: 0.2098 - val_accuracy: 0.9030 - val_loss: 0.2759 - learning_rate: 1.5000e-04
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9223 - loss: 0.2273 - val_accuracy: 0.9030 - val_loss: 0.2757 - learning_rate: 1.5000e-04
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9234 - loss: 0.2265 - val_accuracy: 0.9030 - val_loss: 0.2765 - learning_rate: 1.5000e-04
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9197 - loss: 0.2270 - val_accuracy: 0.9018 - val_loss: 0.2746 - learning_rate: 1.5000e-04
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9283 - loss: 0.2159 - val_accuracy: 0.9030 - val_loss: 0.2742 - learning_rate: 1.5000e-04
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9264 - loss: 0.2201 - val_accuracy: 0.9030 - val_loss: 0.2768 - learning_rate: 1.5000e-04
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9248 - loss: 0.2255 - val_accuracy: 0.9041 - val_loss: 0.2761 - learning_rate: 1.5000e-04
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9219 - loss: 0.2186 - val_accuracy: 0.9041 - val_loss: 0.2754 - learning_rate: 1.5000e-04
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9203 - loss: 0.2329 - val_accuracy: 0.9041 - val_loss: 0.2750 - learning_rate: 1.5000e-04
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9290 - loss: 0.2202 - val_accuracy: 0.9041 - val_loss: 0.2750 - learning_rate: 1.5000e-04
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9264 - loss: 0.2184 - val_accuracy: 0.9041 - val_loss: 0.2754 - learning_rate: 4.5000e-05
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9201 - loss: 0.2151 - val_accuracy: 0.9041 - val_loss: 0.2733 - learning_rate: 4.5000e-05
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9223 - loss: 0.2298 - val_accuracy: 0.9041 - val_loss: 0.2738 - learning_rate: 4.5000e-05
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9237 - loss: 0.2189 - val_accuracy: 0.9053 - val_loss: 0.2747 - learning_rate: 4.5000e-05
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9223 - loss: 0.2230 - val_accuracy: 0.9053 - val_loss: 0.2747 - learning_rate: 4.5000e-05
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9309 - loss: 0.2179 - val_accuracy: 0.9053 - val_loss: 0.2742 - learning_rate: 4.5000e-05
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9322 - loss: 0.2176 - val_accuracy: 0.9053 - val_loss: 0.2737 - learning_rate: 4.5000e-05
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9252 - loss: 0.2226 - val_accuracy: 0.9053 - val_loss: 0.2736 - learning_rate: 1.3500e-05
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9287 - loss: 0.2161 - val_accuracy: 0.9053 - val_loss: 0.2738 - learning_rate: 1.3500e-05
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9266 - loss: 0.2114 - val_accuracy: 0.9053 - val_loss: 0.2744 - learning_rate: 1.3500e-05
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9282 - loss: 0.2012 - val_accuracy: 0.9053 - val_loss: 0.2740 - learning_rate: 1.3500e-05
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9227 - loss: 0.2192 - val_accuracy: 0.9053 - val_loss: 0.2743 - learning_rate: 1.3500e-05
# ✅ Model training completed!

# %%
#==============================================================================
# Step 7: Plot training history and detect overfitting
#==============================================================================

plot_training_history(history)
is_overfitting = detect_overfitting(history)
# Out:
# === Overfitting Analysis ===
# Average Training Accuracy (last 10 epochs): 0.9291
# Average Validation Accuracy (last 10 epochs): 0.9052
# Accuracy Gap: 0.0239
# ✅ Model appears well-balanced (gap <= 0.1)

# %%
#==============================================================================
# Step 8: Validation predictions and evaluation
#==============================================================================

print("\n=== Validation Results ===")
val_pred_labels, val_pred_proba = model.predict(X_val)
val_metrics = calculate_and_plot_metrics(y_val, val_pred_labels, model.label_names, "Validation Confusion Matrix")

print("Validation Metrics:")
for metric, value in val_metrics.items():
    print(f"  {metric}: {value:.4f}")
# Out:
# === Validation Results ===
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Validation Metrics:
#   Accuracy: 0.9041
#   Precision: 0.9044
#   Recall: 0.9041
#   F1-Score (Weighted): 0.9042
#   F1-Score (Macro): 0.9051

# %%
#==============================================================================
# Step 9: Test predictions and evaluation
#==============================================================================

print("\n=== Test Results ===")
test_pred_labels, test_pred_proba = model.predict(X_test)
test_metrics = calculate_and_plot_metrics(y_test, test_pred_labels, model.label_names, "Test Confusion Matrix")

print("Test Metrics:")
for metric, value in test_metrics.items():
    print(f"  {metric}: {value:.4f}")
# Out:
# === Test Results ===
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Metrics:
#   Accuracy: 0.9148
#   Precision: 0.9158
#   Recall: 0.9148
#   F1-Score (Weighted): 0.9151
#   F1-Score (Macro): 0.9152

# %%
#==============================================================================
# Step 10: Detailed classification reports
#==============================================================================

print("\n=== Detailed Classification Report (Validation) ===")
print(classification_report(y_val, val_pred_labels,
                          target_names=model.label_names))

print("\n=== Detailed Classification Report (Test) ===")
print(classification_report(y_test, test_pred_labels,
                          target_names=model.label_names))
# Out:
# === Detailed Classification Report (Validation) ===
#               precision    recall  f1-score   support
#
#          Low       0.94      0.94      0.94       278
#       Medium       0.86      0.87      0.87       297
#         High       0.92      0.90      0.91       270
#
#     accuracy                           0.90       845
#    macro avg       0.91      0.90      0.91       845
# weighted avg       0.90      0.90      0.90       845
#
#
# === Detailed Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#          Low       0.95      0.95      0.95       274
#       Medium       0.86      0.89      0.87       280
#         High       0.94      0.90      0.92       291
#
#     accuracy                           0.91       845
#    macro avg       0.92      0.92      0.92       845
# weighted avg       0.92      0.91      0.92       845

# %%
#==============================================================================
# Step 11: Final summary comparison
#==============================================================================

print("\n=== Model Performance Summary ===")
print(f"{'Metric':<20} {'Validation':<12} {'Test':<12}")
print("-" * 44)
for metric in val_metrics.keys():
    print(f"{metric:<20} {val_metrics[metric]:<12.4f} {test_metrics[metric]:<12.4f}")

print("\n✅ Complete analysis finished!")
# Out:
# === Model Performance Summary ===
# Metric               Validation   Test
# --------------------------------------------
# Accuracy             0.9041       0.9148
# Precision            0.9044       0.9158
# Recall               0.9041       0.9148
# F1-Score (Weighted)  0.9042       0.9151
# F1-Score (Macro)     0.9051       0.9152
#
# ✅ Complete analysis finished!
