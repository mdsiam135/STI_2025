# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/thesis_2025/blob/main/RNN(3_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# RNN for Crop Production Classification (3 Classes)

# This script demonstrates how to build and train a Recurrent Neural Network (RNN)
# for classifying crop production levels into 3 classes based on tabular data using TensorFlow/Keras.

## 1. Setup and Imports

# Import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# Define file paths for session upload
TRAIN_PATH = "/content/drive/MyDrive/UpdatedDataset/train.csv"
VALID_PATH = "/content/drive/MyDrive/UpdatedDataset/validation.csv"
TEST_PATH = "/content/drive/MyDrive/UpdatedDataset/test.csv"

# %%
## 2. Load and Preprocess Data

def load_and_preprocess(file_path, scaler=None, fit_scaler=False, label_encoder=None, fit_encoder=False):
    """Loads data, preprocesses features, and converts target to 3 classes."""
    df = pd.read_csv(file_path)

    # Define class boundaries based on quantiles for 3 classes
    # Using 33rd and 66th percentiles for even distribution
    if fit_scaler:  # Only compute quantiles on training data
        quantiles = np.quantile(df["Production (M.Ton)"], [0.33, 0.66])
        feature_scaler = StandardScaler()
    else:
        # These will be provided from training data
        if scaler is None:
            raise ValueError("Scaler must be provided if fit_scaler is False")
        quantiles, feature_scaler = scaler  # Unpack the tuple of (quantiles, feature_scaler)

    # Create class labels based on quantiles
    bins = [-np.inf, quantiles[0], quantiles[1], np.inf]
    labels = ["low", "medium", "high"]

    # Convert target variable to classes
    df["Production_Category"] = pd.cut(df["Production (M.Ton)"], bins=bins, labels=labels, right=True)

    # Separate features and target
    X = df.drop(["Production (M.Ton)", "Production_Category"], axis=1)
    y = df["Production_Category"]

    # Identify numerical features (excluding one-hot encoded Crop and District)
    # Assuming columns starting with 'Crop_' or 'District_' are one-hot encoded
    numerical_cols = [col for col in X.columns if not col.startswith("Crop_") and not col.startswith("District_")]

    # Scale numerical features
    if fit_scaler:
        X[numerical_cols] = feature_scaler.fit_transform(X[numerical_cols])
    else:
        X[numerical_cols] = feature_scaler.transform(X[numerical_cols])

    # Encode labels
    if fit_encoder:
        le = LabelEncoder()
        y_encoded = le.fit_transform(y)
    else:
        if label_encoder is None:
            raise ValueError("LabelEncoder must be provided if fit_encoder is False")
        y_encoded = label_encoder.transform(y)

    # Convert labels to one-hot encoding
    y_one_hot = tf.keras.utils.to_categorical(y_encoded, num_classes=len(labels))

    # For RNN, reshape features to sequence format: (samples, timesteps, features)
    # We'll treat each feature as a timestep in a sequence
    X_reshaped = X.values.reshape((X.shape[0], X.shape[1], 1))

    if fit_scaler and fit_encoder:
        return X_reshaped, y_one_hot, (quantiles, feature_scaler), le
    elif fit_scaler:
         return X_reshaped, y_one_hot, (quantiles, feature_scaler)
    elif fit_encoder:
        return X_reshaped, y_one_hot, label_encoder
    else:
        return X_reshaped, y_one_hot

# Load and preprocess data
print("Loading and preprocessing training data...")
X_train, y_train, scalers, label_encoder = load_and_preprocess(TRAIN_PATH, fit_scaler=True, fit_encoder=True)

print("Loading and preprocessing validation data...")
X_val, y_val = load_and_preprocess(VALID_PATH, scaler=scalers, label_encoder=label_encoder)

print("Loading and preprocessing test data...")
X_test, y_test = load_and_preprocess(TEST_PATH, scaler=scalers, label_encoder=label_encoder)

quantiles, feature_scaler = scalers

print(f"Training data shape: {X_train.shape}, Labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}, Labels shape: {y_val.shape}")
print(f"Test data shape: {X_test.shape}, Labels shape: {y_test.shape}")
print(f"Number of classes: {y_train.shape[1]}")
print(f"Class boundaries (quantiles): {quantiles}")
print(f"Class names: {label_encoder.classes_}")
# Out:
# Loading and preprocessing training data...
# Loading and preprocessing validation data...
# Loading and preprocessing test data...
# Training data shape: (3942, 83, 1), Labels shape: (3942, 3)
# Validation data shape: (845, 83, 1), Labels shape: (845, 3)
# Test data shape: (845, 83, 1), Labels shape: (845, 3)
# Number of classes: 3
# Class boundaries (quantiles): [1071.5565 3900.1916]
# Class names: ['high' 'low' 'medium']

# %%
## 3. Build the RNN Model

def build_rnn_model(input_shape, num_classes):
    """Builds the RNN model for tabular data classification."""
    model = keras.Sequential([
        # Input layer
        keras.Input(shape=input_shape),

        # RNN layers
        layers.SimpleRNN(64, return_sequences=True),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.SimpleRNN(128),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        # Dense layers for classification
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

# Get input shape and number of classes from preprocessed data
input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
num_classes = y_train.shape[1]  # 3 classes

# Build the model
model = build_rnn_model(input_shape, num_classes)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 83, 64)         │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 83, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 83, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 128)            │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,147 (149.01 KB)
#  Trainable params: 37,763 (147.51 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
## 4. Train the Model

# Define training parameters
EPOCHS = 100
BATCH_SIZE = 64

# Add Early Stopping to prevent overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=15,
    restore_best_weights=True
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.3725 - loss: 1.5526 - val_accuracy: 0.3763 - val_loss: 1.1069
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.3783 - loss: 1.2177 - val_accuracy: 0.4095 - val_loss: 1.0399
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4499 - loss: 1.1054 - val_accuracy: 0.4769 - val_loss: 0.9733
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.5045 - loss: 1.0060 - val_accuracy: 0.6024 - val_loss: 0.8673
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.5634 - loss: 0.9116 - val_accuracy: 0.5799 - val_loss: 0.8413
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.6018 - loss: 0.8472 - val_accuracy: 0.6568 - val_loss: 0.7724
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.6243 - loss: 0.8048 - val_accuracy: 0.6615 - val_loss: 0.7769
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.6348 - loss: 0.8009 - val_accuracy: 0.5858 - val_loss: 0.8336
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.6104 - loss: 0.8200 - val_accuracy: 0.5467 - val_loss: 0.9779
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.6310 - loss: 0.8096 - val_accuracy: 0.6284 - val_loss: 0.7879
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.6577 - loss: 0.7481 - val_accuracy: 0.6142 - val_loss: 0.8100
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.6649 - loss: 0.7487 - val_accuracy: 0.6793 - val_loss: 0.7215
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.6971 - loss: 0.6707 - val_accuracy: 0.6698 - val_loss: 0.7335
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.7125 - loss: 0.6572 - val_accuracy: 0.6781 - val_loss: 0.7298
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.6993 - loss: 0.6633 - val_accuracy: 0.6888 - val_loss: 0.7062
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.7179 - loss: 0.6425 - val_accuracy: 0.7302 - val_loss: 0.6165
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7393 - loss: 0.5985 - val_accuracy: 0.7018 - val_loss: 0.6345
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7621 - loss: 0.5715 - val_accuracy: 0.7053 - val_loss: 0.6854
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.7422 - loss: 0.6042 - val_accuracy: 0.7053 - val_loss: 0.6651
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7566 - loss: 0.5789 - val_accuracy: 0.7112 - val_loss: 0.6356
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7431 - loss: 0.6063 - val_accuracy: 0.7645 - val_loss: 0.5590
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7718 - loss: 0.5491 - val_accuracy: 0.7195 - val_loss: 0.6396
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.7804 - loss: 0.5325 - val_accuracy: 0.7538 - val_loss: 0.5615
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.7779 - loss: 0.5381 - val_accuracy: 0.7550 - val_loss: 0.5707
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.7781 - loss: 0.5331 - val_accuracy: 0.7822 - val_loss: 0.5123
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.7683 - loss: 0.5410 - val_accuracy: 0.7763 - val_loss: 0.5282
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7844 - loss: 0.4942 - val_accuracy: 0.7467 - val_loss: 0.5743
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7767 - loss: 0.5378 - val_accuracy: 0.7645 - val_loss: 0.5487
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.7822 - loss: 0.5073 - val_accuracy: 0.7740 - val_loss: 0.5282
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.7936 - loss: 0.5132 - val_accuracy: 0.7775 - val_loss: 0.4936
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.8226 - loss: 0.4455 - val_accuracy: 0.7657 - val_loss: 0.5255
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8149 - loss: 0.4557 - val_accuracy: 0.7657 - val_loss: 0.5295
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.8206 - loss: 0.4406 - val_accuracy: 0.8024 - val_loss: 0.4652
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.8121 - loss: 0.4494 - val_accuracy: 0.7491 - val_loss: 0.5783
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8172 - loss: 0.4670 - val_accuracy: 0.7976 - val_loss: 0.4787
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step - accuracy: 0.8274 - loss: 0.4167 - val_accuracy: 0.7822 - val_loss: 0.5153
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.8223 - loss: 0.4239 - val_accuracy: 0.7870 - val_loss: 0.4954
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.8365 - loss: 0.4068 - val_accuracy: 0.8047 - val_loss: 0.4778
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.8454 - loss: 0.3975 - val_accuracy: 0.8024 - val_loss: 0.4846
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8283 - loss: 0.4303 - val_accuracy: 0.8189 - val_loss: 0.4374
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8360 - loss: 0.4014 - val_accuracy: 0.8237 - val_loss: 0.4441
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.8442 - loss: 0.3881 - val_accuracy: 0.8047 - val_loss: 0.4873
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.8395 - loss: 0.3890 - val_accuracy: 0.7988 - val_loss: 0.5448
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8316 - loss: 0.4167 - val_accuracy: 0.8296 - val_loss: 0.4327
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8473 - loss: 0.3848 - val_accuracy: 0.8201 - val_loss: 0.4291
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.8436 - loss: 0.3771 - val_accuracy: 0.8118 - val_loss: 0.4444
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8431 - loss: 0.3911 - val_accuracy: 0.8012 - val_loss: 0.4851
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8349 - loss: 0.3960 - val_accuracy: 0.8166 - val_loss: 0.4791
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.8495 - loss: 0.3708 - val_accuracy: 0.8154 - val_loss: 0.4998
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8489 - loss: 0.3977 - val_accuracy: 0.8414 - val_loss: 0.4191
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.8679 - loss: 0.3273 - val_accuracy: 0.8331 - val_loss: 0.4338
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.8474 - loss: 0.3612 - val_accuracy: 0.8071 - val_loss: 0.4881
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8371 - loss: 0.4265 - val_accuracy: 0.8509 - val_loss: 0.4148
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.8555 - loss: 0.3444 - val_accuracy: 0.8462 - val_loss: 0.4421
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.8684 - loss: 0.3301 - val_accuracy: 0.8473 - val_loss: 0.4339
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.8436 - loss: 0.3625 - val_accuracy: 0.8533 - val_loss: 0.4025
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.8734 - loss: 0.3428 - val_accuracy: 0.8580 - val_loss: 0.3932
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.8581 - loss: 0.3421 - val_accuracy: 0.8485 - val_loss: 0.4221
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8639 - loss: 0.3521 - val_accuracy: 0.8000 - val_loss: 0.5539
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8590 - loss: 0.3618 - val_accuracy: 0.8391 - val_loss: 0.4432
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8798 - loss: 0.3158 - val_accuracy: 0.8402 - val_loss: 0.4111
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8660 - loss: 0.3316 - val_accuracy: 0.8284 - val_loss: 0.4255
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.8819 - loss: 0.3226 - val_accuracy: 0.8438 - val_loss: 0.4031
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8892 - loss: 0.3129 - val_accuracy: 0.8343 - val_loss: 0.4321
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8708 - loss: 0.3177 - val_accuracy: 0.8284 - val_loss: 0.4231
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.8773 - loss: 0.3218 - val_accuracy: 0.8142 - val_loss: 0.4943
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.8734 - loss: 0.3248 - val_accuracy: 0.8379 - val_loss: 0.4261
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.8837 - loss: 0.2915 - val_accuracy: 0.8320 - val_loss: 0.4450
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.8816 - loss: 0.3081 - val_accuracy: 0.8296 - val_loss: 0.4807
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.8651 - loss: 0.3410 - val_accuracy: 0.8473 - val_loss: 0.4331
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.8724 - loss: 0.3248 - val_accuracy: 0.8497 - val_loss: 0.4016
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8675 - loss: 0.3303 - val_accuracy: 0.8331 - val_loss: 0.4590

# %%
## 5. Evaluate the Model on Validation Set

# Get best validation accuracy from history
if 'val_accuracy' in history.history:
    best_val_accuracy = max(history.history['val_accuracy'])
    print(f"\nBest Validation Accuracy: {best_val_accuracy:.4f}")
else:
    print("\nValidation accuracy not available in history.")

# Evaluate the trained model on the validation dataset
print("\nEvaluating model on validation data...")
val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")

# Generate predictions on validation set
print("\nGenerating predictions on validation data...")
y_val_pred_proba = model.predict(X_val)
y_val_pred = np.argmax(y_val_pred_proba, axis=1)

# Convert one-hot encoded y_val back to single labels for comparison
y_val_labels = np.argmax(y_val, axis=1)

# Print Validation Classification Report
print("\nValidation Classification Report (includes Recall and F1-score):")
print(classification_report(y_val_labels, y_val_pred,
                           target_names=label_encoder.classes_,
                           zero_division=0))

# Calculate and print Validation Macro F1 Score
val_macro_f1 = f1_score(y_val_labels, y_val_pred, average='macro', zero_division=0)
print(f"\nValidation Macro F1 Score: {val_macro_f1:.4f}")

# Print Validation Confusion Matrix
print("\nValidation Confusion Matrix:")
val_cm = confusion_matrix(y_val_labels, y_val_pred)
print(val_cm)
# Out:
# Best Validation Accuracy: 0.8580
#
# Evaluating model on validation data...
# Validation Loss: 0.3932
# Validation Accuracy: 0.8580
#
# Generating predictions on validation data...
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
# Validation Classification Report (includes Recall and F1-score):
#               precision    recall  f1-score   support
#
#         high       0.86      0.86      0.86       277
#          low       0.92      0.91      0.92       278
#       medium       0.80      0.80      0.80       290
#
#     accuracy                           0.86       845
#    macro avg       0.86      0.86      0.86       845
# weighted avg       0.86      0.86      0.86       845
#
#
# Validation Macro F1 Score: 0.8589
#
# Validation Confusion Matrix:
# [[239   3  35]
#  [  1 254  23]
#  [ 39  19 232]]

# %%
## 6. Evaluate the Model on Test Set

# Evaluate the trained model on the test dataset
print("\nEvaluating model on test data...")
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Generate predictions on test set
print("\nGenerating predictions on test data...")
y_test_pred_proba = model.predict(X_test)
y_test_pred = np.argmax(y_test_pred_proba, axis=1)

# Convert one-hot encoded y_test back to single labels for comparison
y_test_labels = np.argmax(y_test, axis=1)

# Print Test Classification Report
print("\nTest Classification Report (includes Recall and F1-score):")
print(classification_report(y_test_labels, y_test_pred,
                           target_names=label_encoder.classes_,
                           zero_division=0))

# Calculate and print Test Macro F1 Score
test_macro_f1 = f1_score(y_test_labels, y_test_pred, average='macro', zero_division=0)
print(f"\nTest Macro F1 Score: {test_macro_f1:.4f}")

# Print Test Confusion Matrix
print("\nTest Confusion Matrix:")
test_cm = confusion_matrix(y_test_labels, y_test_pred)
print(test_cm)
# Out:
# Evaluating model on test data...
# Test Loss: 0.3367
# Test Accuracy: 0.8805
#
# Generating predictions on test data...
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Test Classification Report (includes Recall and F1-score):
#               precision    recall  f1-score   support
#
#         high       0.91      0.90      0.90       302
#          low       0.92      0.89      0.91       274
#       medium       0.81      0.85      0.83       269
#
#     accuracy                           0.88       845
#    macro avg       0.88      0.88      0.88       845
# weighted avg       0.88      0.88      0.88       845
#
#
# Test Macro F1 Score: 0.8799
#
# Test Confusion Matrix:
# [[272   5  25]
#  [  3 244  27]
#  [ 25  16 228]]

# %%
## 7. Visualize Results

# Plot training history and confusion matrices

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"])
if 'val_accuracy' in history.history:
    plt.plot(history.history["val_accuracy"])
    plt.legend(["Train", "Validation"], loc="upper left")
else:
    plt.legend(["Train"], loc="upper left")
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"])
if 'val_loss' in history.history:
    plt.plot(history.history["val_loss"])
    plt.legend(["Train", "Validation"], loc="upper left")
else:
    plt.legend(["Train"], loc="upper left")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.tight_layout()
plt.show()

# %%
# Plot Validation Confusion Matrix Heatmap
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.heatmap(val_cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title("Validation Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")

# Plot Test Confusion Matrix Heatmap
plt.subplot(1, 2, 2)
sns.heatmap(test_cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title("Test Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.show()

# %%
## 8. Summary of Results

print("\n" + "="*60)
print("FINAL RESULTS SUMMARY")
print("="*60)
print(f"Best Validation Accuracy: {best_val_accuracy:.4f}")
print(f"Final Validation Accuracy: {val_accuracy:.4f}")
print(f"Validation Macro F1 Score: {val_macro_f1:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Macro F1 Score: {test_macro_f1:.4f}")
print("="*60)

print("\n--- End of Script ---")
# Out:
# ============================================================
# FINAL RESULTS SUMMARY
# ============================================================
# Best Validation Accuracy: 0.8580
# Final Validation Accuracy: 0.8580
# Validation Macro F1 Score: 0.8589
# Test Accuracy: 0.8805
# Test Macro F1 Score: 0.8799
# ============================================================
#
# --- End of Script ---
